# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np
import time
import os
from pynq import Overlay, allocate # PYNQ 라이브러리
import matplotlib.pyplot as plt   

print("PYNQ 환경에서 라이브러리 임포트 완료.")

try:
    print("PYNQ 오버레이 로드 시도...")
    overlay = Overlay('cnn.bit')
    conv_ip = overlay.Conv_IP_0
    dma_image = overlay.axi_dma_0
    dma_filter = overlay.axi_dma_1
    dma_output = overlay.axi_dma_2 
    print("오버레이 및 IP/DMA 성공적으로 로드됨.")
except Exception as e:
    print(f"오버레이 로드 실패: {e}")
    print("PYNQ 환경이 아니거나 .bit/.hwh 파일이 없습니다. 스크립트를 종료합니다.")
    exit()

# AXI-Lite 주소
ADDR_IMAGE_WIDTH    = 0x00
ADDR_INPUT_CHANNEL  = 0x04
ADDR_OUTPUT_CHANNEL = 0x08
ADDR_STRIDE         = 0x0C
ADDR_PADDING        = 0x10
ADDR_START          = 0x14
ADDR_EOC_STATUS     = 0x18

# 데이터 타입
DTYPE_IN = np.int8
DTYPE_IN_BIAS = np.int32 # 32비트 DMA로 W(int8)와 B(int32)를 함께 전송
DTYPE_OUT = np.int32 # 누적기(Accumulator) + Bias 결과

classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# PYNQ 환경에서 라이브러리 임포트 완료.
# PYNQ 오버레이 로드 시도...
# 오버레이 및 IP/DMA 성공적으로 로드됨.

# %%
device = torch.device('cpu')

class SimpleVGG(nn.Module):
    def __init__(self, num_classes=10):
        super(SimpleVGG, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),   # 0
            nn.ReLU(inplace=True),                       # 1
            nn.Conv2d(64, 64, kernel_size=3, padding=1),  # 2
            nn.ReLU(inplace=True),                       # 3
            nn.MaxPool2d(kernel_size=2, stride=2),      # 4
            
            nn.Conv2d(64, 128, kernel_size=3, padding=1), # 5
            nn.ReLU(inplace=True),                       # 6
            nn.Conv2d(128, 128, kernel_size=3, padding=1),# 7
            nn.ReLU(inplace=True),                       # 8
            nn.MaxPool2d(kernel_size=2, stride=2),      # 9
            
            nn.Conv2d(128, 256, kernel_size=3, padding=1),# 10
            nn.ReLU(inplace=True),                       # 11
            nn.Conv2d(256, 256, kernel_size=3, padding=1),# 12
            nn.ReLU(inplace=True),                       # 13
            nn.MaxPool2d(kernel_size=2, stride=2),      # 14
        )
        self.classifier = nn.Sequential(
            nn.Linear(256 * 4 * 4, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(1024, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(1024, num_classes),
        )
    
    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

print("SimpleVGG 모델 정의 완료.")
# Out:
# SimpleVGG 모델 정의 완료.

# %%
def quantize_symmetric_per_tensor(tensor, n_bits=8):
    scale = torch.max(torch.abs(tensor.detach())) / (2**(n_bits - 1) - 1) + 1e-8
    quantized_tensor = torch.round(tensor / scale).clamp(-128, 127).to(torch.int8)
    return quantized_tensor, scale

# %%
def plot_inference_result(image_tensor_cpu, pred_cpu_idx, pred_fpga_idx, true_label_idx, image_index):
    global classes # 전역 'classes' 리스트 사용
    
    try:
        # 1.
        mean = np.array([0.4914, 0.4822, 0.4465]).reshape(3, 1, 1)
        std = np.array([0.2023, 0.1994, 0.2010]).reshape(3, 1, 1)
        
        # 텐서를 numpy로 변환 (이미 CPU에 있어야 함)
        img_np = image_tensor_cpu.cpu().numpy()
        
        # (C, H, W) -> (H, W, C)
        img_unnormalized = (img_np * std + mean).transpose(1, 2, 0)
        
        # [0, 1] 범위로 클리핑
        img_clipped = np.clip(img_unnormalized, 0, 1)
        
        # 2. Plot
        plt.figure(figsize=(6, 6))
        plt.imshow(img_clipped)
        
        # 3. Title
        title_true = f"True: {classes[true_label_idx]}"
        
        if pred_cpu_idx is not None:
            title_cpu = f"CPU Pred: {classes[pred_cpu_idx]}"
            color_cpu = 'green' if pred_cpu_idx == true_label_idx else 'red'
            plt.figtext(0.5, 0.08, title_cpu, ha="center", fontsize=12, color=color_cpu)
        
        title_fpga = f"FPGA Pred: {classes[pred_fpga_idx]}"
        color_fpga = 'green' if pred_fpga_idx == true_label_idx else 'red'
        
        plt.title(f"Image #{image_index}\n{title_true}\n", fontsize=14)
        plt.figtext(0.5, 0.03, title_fpga, ha="center", fontsize=12, color=color_fpga)
        
        plt.axis('off')
        

    except Exception as e:
        print(f"  [플롯 경고] 이미지 #{image_index} 표시 실패: {e}")

# %%
def run_fpga_conv_layer(input_tensor_fp32, layer_index,
                        layer_params, prequantized_data,
                        image_buffer, filter_buffer, output_buffer):
    
    # 0. 레이어 파라미터 추출
    INPUT_CHANNEL = layer_params['ic']
    OUTPUT_CHANNEL = layer_params['oc']
    KERNEL_SIZE = layer_params['k']
    PADDING = layer_params['padding']
    STRIDE = layer_params['stride']
    IMAGE_WIDTH = input_tensor_fp32.shape[2] # Input [1, C, H, W]
    
    # 출력 이미지 크기 계산
    IMAGE_WIDTH_OUT = (IMAGE_WIDTH - KERNEL_SIZE + 2 * PADDING) // STRIDE + 1
    
    # 1. prequantized_data에서 미리 처리된 데이터 로드
    weight_data_padded_int32 = prequantized_data['weight_padded_int32']
    scale_w = prequantized_data['scale_w']
    bias_data_fp32 = prequantized_data['bias_fp32']
    
    input_one_image_fp32 = input_tensor_fp32[0] # [1,C,H,W] -> [C,H,W]

    # 2. 동적 양자화 (Input과 Bias)
    input_q, scale_in_torch = quantize_symmetric_per_tensor(input_one_image_fp32, n_bits=8)
    
    scale_in = scale_in_torch.item()
    
    scale_bias = scale_in * scale_w 
    bias_q = torch.round(bias_data_fp32 / scale_bias).to(torch.int32) # INT32 Bias

    # 3. FPGA 입력용 데이터 준비 (W/B Concat)
    
    # 3-A. Weight: 이미 준비됨
    
    # 3-B. Bias: 동적 양자화
    bias_data_flat_int32 = bias_q.cpu().numpy().flatten()
    
    # 3-C. Concat 
    filter_data_np = np.concatenate((weight_data_padded_int32, bias_data_flat_int32))
    
    # 3-D. Input
    image_data_np_3d = input_q.contiguous().cpu().numpy() # (C, H, W), INT8
    image_data_np = image_data_np_3d.flatten()
    
    # 4. PYNQ DMA 버퍼 할당
    # - 공용 버퍼 사용
    image_len = image_data_np.shape[0] # 1D
    filter_len = filter_data_np.shape[0] # 1D
    
    output_shape_fpga = (IMAGE_WIDTH_OUT, IMAGE_WIDTH_OUT, OUTPUT_CHANNEL) # FPGA 출력 규격: (H, W, N)
    output_total_elements = IMAGE_WIDTH_OUT * IMAGE_WIDTH_OUT * OUTPUT_CHANNEL # 1D
    
    if (image_buffer.shape[0] < image_len or 
        filter_buffer.shape[0] < filter_len or
        output_buffer.shape[0] < output_total_elements):
        print(f"치명적 오류: 레이어 #{layer_index}에서 공용 버퍼 크기 부족.")
        return None

    # 5. AXI-Lite 파라미터 설정
    conv_ip.write(ADDR_IMAGE_WIDTH, IMAGE_WIDTH)
    conv_ip.write(ADDR_INPUT_CHANNEL, INPUT_CHANNEL)
    conv_ip.write(ADDR_OUTPUT_CHANNEL, OUTPUT_CHANNEL)
    conv_ip.write(ADDR_STRIDE, STRIDE)
    conv_ip.write(ADDR_PADDING, PADDING)

    # 6. FPGA 실행
    image_buffer[0:image_len] = image_data_np
    filter_buffer[0:filter_len] = filter_data_np
    output_buffer.fill(0)
    
    image_buffer_view = image_buffer[0:image_len]
    filter_buffer_view = filter_buffer[0:filter_len]
    output_buffer_view = output_buffer[0:output_total_elements]
    
    dma_output.recvchannel.transfer(output_buffer_view)
    dma_filter.sendchannel.transfer(filter_buffer_view)
    dma_image.sendchannel.transfer(image_buffer_view)
    
    conv_ip.write(ADDR_START, 1) # 실행!

    while not (conv_ip.read(ADDR_EOC_STATUS) & 0x1):
        pass
    
    dma_filter.sendchannel.wait()
    dma_image.sendchannel.wait()
    dma_output.recvchannel.wait()

    # 7. 출력 처리 (역양자화 및 Transpose)
    output_fpga_int32_np = np.array(output_buffer_view).reshape(output_shape_fpga)
    output_fpga_int32 = torch.from_numpy(output_fpga_int32_np) # (H, W, N)
    
    output_fp32 = output_fpga_int32.float() * scale_bias
    output_pytorch_fp32 = output_fp32.permute(2, 0, 1) # (N, H, W)

    # 9. 배치 차원(1)을 다시 추가하여 리턴
    final_output_tensor = output_pytorch_fp32.unsqueeze(0).to(device) # [1, N, H, W]
    
    return final_output_tensor

# %%
def pynq_accelerated_inference(model, image_batch,
                               image_buffer_shared, 
                               filter_buffer_shared, 
                               output_buffer_shared,
                               layer_params_list,
                               prequantized_data_list):
    """
    모델의 'features' 모듈을 수동으로 실행하며
    Conv2d는 'run_fpga_conv_layer'로, 나머지는 CPU로 실행.
    """
    
    x = image_batch.to(device) # PYNQ의 CPU로 데이터 이동
    conv_layer_index = 0
    
    try:
        for i, layer in enumerate(model.features):
            
            if isinstance(layer, nn.Conv2d):
                layer_params = layer_params_list[conv_layer_index]
                prequantized_data = prequantized_data_list[conv_layer_index]
                
                x = run_fpga_conv_layer(x, conv_layer_index,
                                        layer_params, 
                                        prequantized_data,
                                        image_buffer_shared, 
                                        filter_buffer_shared, 
                                        output_buffer_shared)
                
                if x is None: # run_fpga_conv_layer에서 오류 발생 시
                    raise Exception(f"FPGA 레이어 {conv_layer_index} 실행 중 오류 발생")
                    
                conv_layer_index += 1
            else:
                # ReLU, MaxPool 등은 PyTorch(CPU)로 실행
                x = layer(x)
                
        # Classifier는 PyTorch(CPU)로 실행
        x = torch.flatten(x, 1)
        x = model.classifier(x)
        
    except Exception as e:
        print(f"추론 중단됨: {e}")
        x = None # 오류 발생 시 None 반환
        
    return x # 정상 결과 또는 None 반환

# %%
print("=" * 50)
print("     [ PYNQ 추론 및 검증 단계 시작 ]")
print("=" * 50)

# Colab에서 학습한 모델 로드
MODEL_PATH = 'simple_vgg_trained.pth'
inference_model = SimpleVGG(num_classes=10).to(device)

try:
    # map_location=device (cpu)로 강제
    inference_model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
    print(f"성공: '{MODEL_PATH}'에서 학습된 가중치를 불러왔습니다.")
except Exception as e:
    print(f"가중치 로드 실패: {e}. (.pth 파일이 필요합니다)")
    # exit()

inference_model.eval() # 추론 모드 설정

# BATCH_SIZE=1로 고정
BATCH_SIZE_PYNQ = 1 
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
# BATCH_SIZE=1, shuffle=False로 1개씩 순서대로 테스트
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=BATCH_SIZE_PYNQ, shuffle=False, num_workers=2)

print(f"테스트 데이터 로더 준비 완료 (배치 크기: {BATCH_SIZE_PYNQ})")
# Out:
# ==================================================
#      [ PYNQ 추론 및 검증 단계 시작 ]
# ==================================================
# 성공: 'simple_vgg_trained.pth'에서 학습된 가중치를 불러왔습니다.
# Files already downloaded and verified
# 테스트 데이터 로더 준비 완료 (배치 크기: 1)

# %%
print("\n[추론 준비] Weight/Bias 사전 처리 및 양자화 시작...")
layer_params_list = []      # FPGA IP 설정값 (IC, OC, Stride...)
prequantized_data_list = [] # 미리 처리된 W/B 텐서

try:
    with torch.no_grad(): # 사전 처리 중에는 그래디언트 필요 없음
        for layer in inference_model.features:
            if isinstance(layer, nn.Conv2d):
                # 1. 레이어 파라미터 추출
                OC, IC, K, _ = layer.weight.shape
                params = {
                    'oc': OC,
                    'ic': IC,
                    'k': K,
                    'padding': layer.padding[0],
                    'stride': layer.stride[0]
                }
                layer_params_list.append(params)
                
                # 2. Weight/Bias 텐서 추출
                weight_data_fp32 = layer.weight.data.cpu()
                bias_data_fp32 = layer.bias.data.cpu()
                
                # 3. Weight만 미리 양자화, 재배열, 패딩
                weight_q, scale_w_torch = quantize_symmetric_per_tensor(weight_data_fp32, n_bits=8)
                weight_q_transposed = weight_q.permute(1, 0, 2, 3) # (IC, OC, K, K)
                weight_q_flat_int8 = weight_q_transposed.cpu().numpy().flatten()
                weight_data_padded_int32 = weight_q_flat_int8.astype(np.int32)
                
                # 4. 리스트에 저장
                data_dict = {
                    'weight_padded_int32': weight_data_padded_int32, # 미리 패딩된 INT32 Weight
                    'scale_w': scale_w_torch.item(),                 # Weight 스케일
                    'bias_fp32': bias_data_fp32                      # 원본 FP32 Bias
                }
                prequantized_data_list.append(data_dict)

    print(f"사전 처리 완료. 총 {len(prequantized_data_list)}개의 Conv 레이어 데이터 준비됨.")
except Exception as e:
    print(f"치명적 오류: Weight/Bias 사전 처리 실패: {e}")
    # exit()
# Out:
# [추론 준비] Weight/Bias 사전 처리 및 양자화 시작...
# 사전 처리 완료. 총 6개의 Conv 레이어 데이터 준비됨.

# %%
RUN_CPU_BENCHMARK = 1

# 버퍼를 루프 밖에서 한 번만 할당
print(f"\n[추론 준비] 공용 DMA 버퍼 할당 시도...")
try:
    MAX_IMAGE_ELEMS = 256 * 32 * 32  
    MAX_FILTER_ELEMS = 590080        
    MAX_OUTPUT_ELEMS = 32 * 32 * 256 
    
    image_buffer_shared = allocate(shape=(MAX_IMAGE_ELEMS,), dtype=DTYPE_IN)
    filter_buffer_shared = allocate(shape=(MAX_FILTER_ELEMS,), dtype=DTYPE_IN_BIAS)
    output_buffer_shared = allocate(shape=(MAX_OUTPUT_ELEMS,), dtype=DTYPE_OUT)
    print("공용 DMA 버퍼 3개 할당 성공.")
except Exception as e:
    print(f"치명적 오류: 공용 DMA 버퍼 할당 실패: {e}")
    print("PYNQ 보드를 재부팅하거나, CMA 메모리가 충분한지 확인하세요.")
    # exit()


NUM_TEST_IMAGES = 1000
print(f"\n테스트셋 *{NUM_TEST_IMAGES}*개 이미지에 대한 정확도 비교 시작...")
if RUN_CPU_BENCHMARK == 0:
    print("  (참고: CPU 벤치마크 [A]가 비활성화되었습니다.)")

correct_a = 0 # [A] PyTorch CPU 추론 카운터
correct_b = 0 # [B] PYNQ FPGA 가속 추론 카운터
total = 0
total_time_a_ms = 0.0 # [성능 비교] 총 CPU 시간
total_time_b_ms = 0.0 # [성능 비교] 총 FPGA 시간


try:
    with torch.no_grad():
        for i, (images, labels) in enumerate(test_loader):
            
            if i >= NUM_TEST_IMAGES:
                print(f"{NUM_TEST_IMAGES}개 이미지 테스트 완료. 루프 종료.")
                break
                
            images, labels = images.to(device), labels.to(device)
            
            time_a_ms = 0.0
            pred_a = None # 플롯 함수가 None을 처리할 수 있도록 함
            
            # (A) 기준점: 순수 PyTorch(CPU)로만 추론
            if RUN_CPU_BENCHMARK == 1:
                start_a = time.time()
                output_a = inference_model(images)
                end_a = time.time()
                _, pred_a = torch.max(output_a.data, 1)
                time_a_ms = (end_a - start_a) * 1000
                total_time_a_ms += time_a_ms
                correct_a += (pred_a == labels).sum().item()

            # (B) 검증 대상: PYNQ FPGA 가속 추론
            start_b = time.time()
            output_b = pynq_accelerated_inference(inference_model, images,
                                                image_buffer_shared,
                                                filter_buffer_shared,
                                                output_buffer_shared,
                                                layer_params_list,
                                                prequantized_data_list)
            end_b = time.time()
            
            # [수정] output_b가 None일 경우(추론 실패) 처리
            if output_b is None:
                print(f"  (B) PYNQ 추론 실패 (이미지 #{i}). 테스트 중단.")
                break
                
            _, pred_b = torch.max(output_b.data, 1) # [오타 수정 완료]

            # 카운트 업데이트
            total += labels.size(0)
            # correct_a는 (A) 블록 내부에서만 업데이트
            correct_b += (pred_b == labels).sum().item() # [오타 수정 완료]

            # 시간 측정 및 출력
            time_b_ms = (end_b - start_b) * 1000
            total_time_b_ms += time_b_ms
            
            if RUN_CPU_BENCHMARK == 1:
                print(f"[이미지 #{i}] Time (CPU): {time_a_ms:8.2f} ms | Time (FPGA): {time_b_ms:8.2f} ms")
            else:
                print(f"[이미지 #{i}] Time (FPGA): {time_b_ms:8.2f} ms")
            # 종료

            # 10의 배수 이미지 플롯
            if i % 10 == 0:
                pred_a_val = pred_a.item() if pred_a is not None else None
                plot_inference_result(images[0], 
                                      pred_a_val, 
                                      pred_b.item(), 
                                      labels.item(), 
                                      i)
            # 종료

finally:
    print("\n공용 DMA 버퍼 해제 중...")
    image_buffer_shared.freebuffer()
    filter_buffer_shared.freebuffer()
    output_buffer_shared.freebuffer()
    del image_buffer_shared
    del filter_buffer_shared
    del output_buffer_shared
    print("공용 DMA 버퍼 모두 해제됨.")


# 최종 최종 정확도 계산
# [수정] total이 0일 경우 ZeroDivisionError 방지
if total > 0:
    accuracy_a = 100 * correct_a / total
    accuracy_b = 100 * correct_b / total
    avg_time_a_ms = total_time_a_ms / total if RUN_CPU_BENCHMARK == 1 else 0.0
    avg_time_b_ms = total_time_b_ms / total
else:
    accuracy_a = 0.0
    accuracy_b = 0.0
    avg_time_a_ms = 0.0
    avg_time_b_ms = 0.0

print("\n" + "=" * 50)
print(f"     *PYNQ 테스트* 최종 정확도 비교 결과 ({total}개 샘플)")
print("=" * 50)
# [신규] CPU 스위치 상태에 따라 조건부 출력
if RUN_CPU_BENCHMARK == 1:
    print(f"  - [A] PyTorch CPU 추론 정확도: \t{accuracy_a:.2f} % ({correct_a}/{total})")
print(f"  - [B] PYNQ FPGA 가속 추론 정확도: \t{accuracy_b:.2f} % ({correct_b}/{total})")
if RUN_CPU_BENCHMARK == 1:
    print("-" * 50)
    print(f"  - 정확도 차이 (A - B): {accuracy_a - accuracy_b:+.2f} %")

print("\n" + "=" * 50)
print(f"     *PYNQ 테스트* 최종 성능 비교 결과 ({total}개 샘플)")
print("=" * 50)
if RUN_CPU_BENCHMARK == 1:
    print(f"  - [A] CPU 평균 추론 시간: \t{avg_time_a_ms:.2f} ms/image")
print(f"  - [B] FPGA 평균 추론 시간: \t{avg_time_b_ms:.2f} ms/image")
print("-" * 50)
if RUN_CPU_BENCHMARK == 1 and avg_time_a_ms > 0:
    speedup = avg_time_a_ms / avg_time_b_ms
    print(f"  - FPGA 가속 성능: {speedup:.2f}x (CPU 대비)")
else:
    print("  - FPGA 가속 성능: (CPU 벤치마크 Off)")

print("\nPYNQ 추론 스크립트 종료.")
# Out:
# [추론 준비] 공용 DMA 버퍼 할당 시도...
# 공용 DMA 버퍼 3개 할당 성공.
#
# 테스트셋 *1000*개 이미지에 대한 정확도 비교 시작...
# [이미지 #0] Time (CPU):  3405.02 ms | Time (FPGA):   275.65 ms
# [이미지 #1] Time (CPU):  3315.34 ms | Time (FPGA):   262.28 ms
# [이미지 #2] Time (CPU):  3316.26 ms | Time (FPGA):   263.57 ms
# [이미지 #3] Time (CPU):  3321.39 ms | Time (FPGA):   262.26 ms
# [이미지 #4] Time (CPU):  3316.81 ms | Time (FPGA):   263.62 ms
# [이미지 #5] Time (CPU):  3315.09 ms | Time (FPGA):   261.96 ms
# [이미지 #6] Time (CPU):  3314.53 ms | Time (FPGA):   263.94 ms
# [이미지 #7] Time (CPU):  3319.49 ms | Time (FPGA):   262.32 ms
# [이미지 #8] Time (CPU):  3319.39 ms | Time (FPGA):   263.57 ms
# [이미지 #9] Time (CPU):  3315.28 ms | Time (FPGA):   262.13 ms
# [이미지 #10] Time (CPU):  3315.51 ms | Time (FPGA):   262.27 ms
# [이미지 #11] Time (CPU):  3314.16 ms | Time (FPGA):   263.38 ms
# [이미지 #12] Time (CPU):  3311.16 ms | Time (FPGA):   262.30 ms
# [이미지 #13] Time (CPU):  3316.98 ms | Time (FPGA):   263.14 ms
# [이미지 #14] Time (CPU):  3312.28 ms | Time (FPGA):   261.65 ms
# [이미지 #15] Time (CPU):  3314.92 ms | Time (FPGA):   263.21 ms
# [이미지 #16] Time (CPU):  3321.37 ms | Time (FPGA):   263.02 ms
# [이미지 #17] Time (CPU):  3313.85 ms | Time (FPGA):   261.91 ms
# [이미지 #18] Time (CPU):  3311.34 ms | Time (FPGA):   262.00 ms
# [이미지 #19] Time (CPU):  3311.20 ms | Time (FPGA):   261.89 ms
# [이미지 #20] Time (CPU):  3310.99 ms | Time (FPGA):   261.91 ms
# [이미지 #21] Time (CPU):  3312.75 ms | Time (FPGA):   262.40 ms
# [이미지 #22] Time (CPU):  3313.11 ms | Time (FPGA):   258.95 ms
# [이미지 #23] Time (CPU):  3309.63 ms | Time (FPGA):   258.35 ms
# [이미지 #24] Time (CPU):  3320.02 ms | Time (FPGA):   264.53 ms
# [이미지 #25] Time (CPU):  3319.72 ms | Time (FPGA):   262.01 ms
# [이미지 #26] Time (CPU):  3315.38 ms | Time (FPGA):   263.57 ms
# [이미지 #27] Time (CPU):  3322.17 ms | Time (FPGA):   338.22 ms
# [이미지 #28] Time (CPU):  3314.04 ms | Time (FPGA):   259.94 ms
# [이미지 #29] Time (CPU):  3316.47 ms | Time (FPGA):   261.85 ms
# [이미지 #30] Time (CPU):  3310.62 ms | Time (FPGA):   261.60 ms
# [이미지 #31] Time (CPU):  3313.96 ms | Time (FPGA):   260.63 ms
# [이미지 #32] Time (CPU):  3320.52 ms | Time (FPGA):   257.99 ms
# [이미지 #33] Time (CPU):  3314.26 ms | Time (FPGA):   257.61 ms
# [이미지 #34] Time (CPU):  3312.24 ms | Time (FPGA):   257.88 ms
# [이미지 #35] Time (CPU):  3309.49 ms | Time (FPGA):   259.26 ms
# [이미지 #36] Time (CPU):  3309.93 ms | Time (FPGA):   259.92 ms
# [이미지 #37] Time (CPU):  3313.70 ms | Time (FPGA):   259.91 ms
# [이미지 #38] Time (CPU):  3310.47 ms | Time (FPGA):   258.22 ms
# [이미지 #39] Time (CPU):  3311.73 ms | Time (FPGA):   258.16 ms
# [이미지 #40] Time (CPU):  3310.03 ms | Time (FPGA):   258.14 ms
# [이미지 #41] Time (CPU):  3322.09 ms | Time (FPGA):   260.52 ms
# [이미지 #42] Time (CPU):  3314.17 ms | Time (FPGA):   258.69 ms
# [이미지 #43] Time (CPU):  3315.34 ms | Time (FPGA):   258.29 ms
# [이미지 #44] Time (CPU):  3316.73 ms | Time (FPGA):   258.11 ms
# [이미지 #45] Time (CPU):  3315.59 ms | Time (FPGA):   258.16 ms
# [이미지 #46] Time (CPU):  3313.99 ms | Time (FPGA):   262.16 ms
# [이미지 #47] Time (CPU):  3312.89 ms | Time (FPGA):   258.46 ms
# [이미지 #48] Time (CPU):  3313.43 ms | Time (FPGA):   259.08 ms
# [이미지 #49] Time (CPU):  3317.56 ms | Time (FPGA):   259.79 ms
# [이미지 #50] Time (CPU):  3315.92 ms | Time (FPGA):   258.27 ms
# [이미지 #51] Time (CPU):  3314.69 ms | Time (FPGA):   265.00 ms
# [이미지 #52] Time (CPU):  3316.55 ms | Time (FPGA):   262.52 ms
# [이미지 #53] Time (CPU):  3315.80 ms | Time (FPGA):   266.38 ms
# [이미지 #54] Time (CPU):  3316.35 ms | Time (FPGA):   261.95 ms
# [이미지 #55] Time (CPU):  3313.62 ms | Time (FPGA):   262.21 ms
# [이미지 #56] Time (CPU):  3314.94 ms | Time (FPGA):   261.88 ms
# [이미지 #57] Time (CPU):  3312.15 ms | Time (FPGA):   261.81 ms
# [이미지 #58] Time (CPU):  3320.86 ms | Time (FPGA):   262.41 ms
# [이미지 #59] Time (CPU):  3314.28 ms | Time (FPGA):   264.57 ms
# [이미지 #60] Time (CPU):  3313.99 ms | Time (FPGA):   261.96 ms
# [이미지 #61] Time (CPU):  3348.70 ms | Time (FPGA):   260.45 ms
# [이미지 #62] Time (CPU):  3313.24 ms | Time (FPGA):   262.66 ms
# [이미지 #63] Time (CPU):  3308.20 ms | Time (FPGA):   259.57 ms
# [이미지 #64] Time (CPU):  3309.85 ms | Time (FPGA):   259.99 ms
# [이미지 #65] Time (CPU):  3311.02 ms | Time (FPGA):   261.36 ms
# [이미지 #66] Time (CPU):  3314.63 ms | Time (FPGA):   260.46 ms
# [이미지 #67] Time (CPU):  3309.36 ms | Time (FPGA):   261.25 ms
# [이미지 #68] Time (CPU):  3309.67 ms | Time (FPGA):   259.33 ms
# [이미지 #69] Time (CPU):  3312.04 ms | Time (FPGA):   259.51 ms
# [이미지 #70] Time (CPU):  3310.13 ms | Time (FPGA):   259.24 ms
# [이미지 #71] Time (CPU):  3315.71 ms | Time (FPGA):   263.26 ms
# [이미지 #72] Time (CPU):  3311.15 ms | Time (FPGA):   259.55 ms
# [이미지 #73] Time (CPU):  3310.97 ms | Time (FPGA):   259.40 ms
# [이미지 #74] Time (CPU):  3315.13 ms | Time (FPGA):   259.89 ms
# [이미지 #75] Time (CPU):  3315.05 ms | Time (FPGA):   259.94 ms
# [이미지 #76] Time (CPU):  3312.62 ms | Time (FPGA):   261.13 ms
# [이미지 #77] Time (CPU):  3309.96 ms | Time (FPGA):   259.12 ms
# [이미지 #78] Time (CPU):  3311.62 ms | Time (FPGA):   259.45 ms
# [이미지 #79] Time (CPU):  3311.22 ms | Time (FPGA):   259.41 ms
# [이미지 #80] Time (CPU):  3310.96 ms | Time (FPGA):   259.51 ms
# [이미지 #81] Time (CPU):  3310.89 ms | Time (FPGA):   263.01 ms
# [이미지 #82] Time (CPU):  3310.00 ms | Time (FPGA):   262.37 ms
# [이미지 #83] Time (CPU):  3319.77 ms | Time (FPGA):   262.74 ms
# [이미지 #84] Time (CPU):  3316.83 ms | Time (FPGA):   266.16 ms
# [이미지 #85] Time (CPU):  3314.11 ms | Time (FPGA):   260.86 ms
# [이미지 #86] Time (CPU):  3315.80 ms | Time (FPGA):   263.03 ms
# [이미지 #87] Time (CPU):  3313.96 ms | Time (FPGA):   262.04 ms
# [이미지 #88] Time (CPU):  3311.33 ms | Time (FPGA):   263.33 ms
# [이미지 #89] Time (CPU):  3314.16 ms | Time (FPGA):   262.20 ms
# [이미지 #90] Time (CPU):  3314.71 ms | Time (FPGA):   261.36 ms
# [이미지 #91] Time (CPU):  3320.03 ms | Time (FPGA):   264.38 ms
# [이미지 #92] Time (CPU):  3316.02 ms | Time (FPGA):   262.26 ms
# [이미지 #93] Time (CPU):  3313.37 ms | Time (FPGA):   263.53 ms
# [이미지 #94] Time (CPU):  3322.33 ms | Time (FPGA):   262.53 ms
# [이미지 #95] Time (CPU):  3312.19 ms | Time (FPGA):   262.58 ms
# [이미지 #96] Time (CPU):  3314.39 ms | Time (FPGA):   261.74 ms
# [이미지 #97] Time (CPU):  3320.46 ms | Time (FPGA):   262.25 ms
# [이미지 #98] Time (CPU):  3318.23 ms | Time (FPGA):   262.03 ms
# [이미지 #99] Time (CPU):  3318.34 ms | Time (FPGA):   262.09 ms
# [이미지 #100] Time (CPU):  3327.93 ms | Time (FPGA):   263.84 ms
# [이미지 #101] Time (CPU):  3316.70 ms | Time (FPGA):   261.30 ms
# [이미지 #102] Time (CPU):  3314.41 ms | Time (FPGA):   261.18 ms
# [이미지 #103] Time (CPU):  3311.90 ms | Time (FPGA):   259.76 ms
# [이미지 #104] Time (CPU):  3311.21 ms | Time (FPGA):   259.18 ms
# [이미지 #105] Time (CPU):  3311.70 ms | Time (FPGA):   259.43 ms
# [이미지 #106] Time (CPU):  3309.53 ms | Time (FPGA):   260.02 ms
# [이미지 #107] Time (CPU):  3309.60 ms | Time (FPGA):   259.36 ms
# [이미지 #108] Time (CPU):  3317.23 ms | Time (FPGA):   259.63 ms
# [이미지 #109] Time (CPU):  3311.75 ms | Time (FPGA):   259.51 ms
# [이미지 #110] Time (CPU):  3310.32 ms | Time (FPGA):   257.66 ms
# [이미지 #111] Time (CPU):  3310.68 ms | Time (FPGA):   258.30 ms
# [이미지 #112] Time (CPU):  3311.43 ms | Time (FPGA):   257.76 ms
# [이미지 #113] Time (CPU):  3309.49 ms | Time (FPGA):   257.81 ms
# [이미지 #114] Time (CPU):  3311.75 ms | Time (FPGA):   258.00 ms
# [이미지 #115] Time (CPU):  3314.61 ms | Time (FPGA):   262.77 ms
# [이미지 #116] Time (CPU):  3315.55 ms | Time (FPGA):   259.27 ms
# [이미지 #117] Time (CPU):  3311.64 ms | Time (FPGA):   261.74 ms
# [이미지 #118] Time (CPU):  3311.74 ms | Time (FPGA):   260.29 ms
# [이미지 #119] Time (CPU):  3315.85 ms | Time (FPGA):   258.62 ms
# [이미지 #120] Time (CPU):  3314.42 ms | Time (FPGA):   260.13 ms
# [이미지 #121] Time (CPU):  3311.89 ms | Time (FPGA):   260.35 ms
# [이미지 #122] Time (CPU):  3309.14 ms | Time (FPGA):   261.51 ms
# [이미지 #123] Time (CPU):  3310.72 ms | Time (FPGA):   260.35 ms
# [이미지 #124] Time (CPU):  3314.54 ms | Time (FPGA):   261.06 ms
# [이미지 #125] Time (CPU):  3313.00 ms | Time (FPGA):   259.91 ms
# [이미지 #126] Time (CPU):  3313.93 ms | Time (FPGA):   260.02 ms
# [이미지 #127] Time (CPU):  3326.62 ms | Time (FPGA):   271.26 ms
# [이미지 #128] Time (CPU):  3307.79 ms | Time (FPGA):   259.72 ms
# [이미지 #129] Time (CPU):  3310.55 ms | Time (FPGA):   259.61 ms
# [이미지 #130] Time (CPU):  3308.62 ms | Time (FPGA):   259.70 ms
# [이미지 #131] Time (CPU):  3308.09 ms | Time (FPGA):   261.07 ms
# [이미지 #132] Time (CPU):  3310.07 ms | Time (FPGA):   259.70 ms
# [이미지 #133] Time (CPU):  3320.49 ms | Time (FPGA):   260.77 ms
# [이미지 #134] Time (CPU):  3312.38 ms | Time (FPGA):   263.76 ms
# [이미지 #135] Time (CPU):  3309.49 ms | Time (FPGA):   259.53 ms
# [이미지 #136] Time (CPU):  3310.01 ms | Time (FPGA):   260.02 ms
# [이미지 #137] Time (CPU):  3308.73 ms | Time (FPGA):   259.99 ms
# [이미지 #138] Time (CPU):  3309.94 ms | Time (FPGA):   259.67 ms
# [이미지 #139] Time (CPU):  3309.07 ms | Time (FPGA):   259.73 ms
# [이미지 #140] Time (CPU):  3308.28 ms | Time (FPGA):   260.09 ms
# [이미지 #141] Time (CPU):  3308.63 ms | Time (FPGA):   261.84 ms
# [이미지 #142] Time (CPU):  3319.60 ms | Time (FPGA):   262.13 ms
# [이미지 #143] Time (CPU):  3312.93 ms | Time (FPGA):   265.86 ms
# [이미지 #144] Time (CPU):  3310.64 ms | Time (FPGA):   262.63 ms
# [이미지 #145] Time (CPU):  3315.80 ms | Time (FPGA):   262.01 ms
# [이미지 #146] Time (CPU):  3317.97 ms | Time (FPGA):   264.09 ms
# [이미지 #147] Time (CPU):  3312.63 ms | Time (FPGA):   261.95 ms
# [이미지 #148] Time (CPU):  3312.38 ms | Time (FPGA):   261.59 ms
# [이미지 #149] Time (CPU):  3310.39 ms | Time (FPGA):   261.81 ms
# [이미지 #150] Time (CPU):  3319.73 ms | Time (FPGA):   262.72 ms
# [이미지 #151] Time (CPU):  3317.62 ms | Time (FPGA):   264.19 ms
# [이미지 #152] Time (CPU):  3314.57 ms | Time (FPGA):   261.17 ms
# [이미지 #153] Time (CPU):  3310.76 ms | Time (FPGA):   262.16 ms
# [이미지 #154] Time (CPU):  3309.55 ms | Time (FPGA):   259.65 ms
# [이미지 #155] Time (CPU):  3311.03 ms | Time (FPGA):   259.41 ms
# [이미지 #156] Time (CPU):  3320.91 ms | Time (FPGA):   260.00 ms
# [이미지 #157] Time (CPU):  3309.12 ms | Time (FPGA):   259.49 ms
# [이미지 #158] Time (CPU):  3318.85 ms | Time (FPGA):   268.64 ms
# [이미지 #159] Time (CPU):  3313.69 ms | Time (FPGA):   263.08 ms
# [이미지 #160] Time (CPU):  3308.79 ms | Time (FPGA):   260.82 ms
# [이미지 #161] Time (CPU):  3339.76 ms | Time (FPGA):   259.54 ms
# [이미지 #162] Time (CPU):  3311.92 ms | Time (FPGA):   258.61 ms
# [이미지 #163] Time (CPU):  3312.36 ms | Time (FPGA):   258.53 ms
# [이미지 #164] Time (CPU):  3312.77 ms | Time (FPGA):   259.53 ms
# [이미지 #165] Time (CPU):  3312.49 ms | Time (FPGA):   258.94 ms
# [이미지 #166] Time (CPU):  3309.00 ms | Time (FPGA):   259.39 ms
# [이미지 #167] Time (CPU):  3314.55 ms | Time (FPGA):   259.02 ms
# [이미지 #168] Time (CPU):  3314.64 ms | Time (FPGA):   257.95 ms
# [이미지 #169] Time (CPU):  3309.33 ms | Time (FPGA):   259.57 ms
# [이미지 #170] Time (CPU):  3311.29 ms | Time (FPGA):   258.17 ms
# [이미지 #171] Time (CPU):  3312.80 ms | Time (FPGA):   260.13 ms
# [이미지 #172] Time (CPU):  3307.64 ms | Time (FPGA):   257.92 ms
# [이미지 #173] Time (CPU):  3307.77 ms | Time (FPGA):   257.82 ms
# [이미지 #174] Time (CPU):  3307.04 ms | Time (FPGA):   258.34 ms
# [이미지 #175] Time (CPU):  3312.33 ms | Time (FPGA):   258.01 ms
# [이미지 #176] Time (CPU):  3310.13 ms | Time (FPGA):   259.28 ms
# [이미지 #177] Time (CPU):  3308.93 ms | Time (FPGA):   257.96 ms
# [이미지 #178] Time (CPU):  3310.12 ms | Time (FPGA):   262.49 ms
# [이미지 #179] Time (CPU):  3311.57 ms | Time (FPGA):   261.88 ms
# [이미지 #180] Time (CPU):  3307.74 ms | Time (FPGA):   259.32 ms
# [이미지 #181] Time (CPU):  3306.18 ms | Time (FPGA):   261.59 ms
# [이미지 #182] Time (CPU):  3307.41 ms | Time (FPGA):   262.40 ms
# [이미지 #183] Time (CPU):  3311.05 ms | Time (FPGA):   262.50 ms
# [이미지 #184] Time (CPU):  3322.57 ms | Time (FPGA):   262.67 ms
# [이미지 #185] Time (CPU):  3312.64 ms | Time (FPGA):   264.08 ms
# [이미지 #186] Time (CPU):  3310.77 ms | Time (FPGA):   261.75 ms
# [이미지 #187] Time (CPU):  3308.06 ms | Time (FPGA):   262.17 ms
# [이미지 #188] Time (CPU):  3307.98 ms | Time (FPGA):   261.62 ms
# [이미지 #189] Time (CPU):  3311.52 ms | Time (FPGA):   261.80 ms
# [이미지 #190] Time (CPU):  3308.52 ms | Time (FPGA):   261.26 ms
# [이미지 #191] Time (CPU):  3314.21 ms | Time (FPGA):   263.48 ms
# [이미지 #192] Time (CPU):  3313.51 ms | Time (FPGA):   258.91 ms
# [이미지 #193] Time (CPU):  3311.71 ms | Time (FPGA):   259.94 ms
# [이미지 #194] Time (CPU):  3318.21 ms | Time (FPGA):   257.74 ms
# [이미지 #195] Time (CPU):  3309.70 ms | Time (FPGA):   257.86 ms
# [이미지 #196] Time (CPU):  3309.02 ms | Time (FPGA):   258.02 ms
# [이미지 #197] Time (CPU):  3312.92 ms | Time (FPGA):   257.98 ms
# [이미지 #198] Time (CPU):  3309.09 ms | Time (FPGA):   257.72 ms
# [이미지 #199] Time (CPU):  3314.37 ms | Time (FPGA):   258.08 ms
# [이미지 #200] Time (CPU):  3312.66 ms | Time (FPGA):   264.28 ms
# <ipython-input-65-eb1fda1695f2>:25: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(6, 6))
# [이미지 #201] Time (CPU):  3309.44 ms | Time (FPGA):   264.19 ms
# [이미지 #202] Time (CPU):  3310.29 ms | Time (FPGA):   261.71 ms
# [이미지 #203] Time (CPU):  3307.63 ms | Time (FPGA):   261.55 ms
# [이미지 #204] Time (CPU):  3311.92 ms | Time (FPGA):   265.20 ms
# [이미지 #205] Time (CPU):  3314.74 ms | Time (FPGA):   261.14 ms
# [이미지 #206] Time (CPU):  3310.77 ms | Time (FPGA):   262.60 ms
# [이미지 #207] Time (CPU):  3306.45 ms | Time (FPGA):   260.99 ms
# [이미지 #208] Time (CPU):  3314.16 ms | Time (FPGA):   261.75 ms
# [이미지 #209] Time (CPU):  3313.69 ms | Time (FPGA):   261.10 ms
# [이미지 #210] Time (CPU):  3310.78 ms | Time (FPGA):   261.36 ms
# [이미지 #211] Time (CPU):  3309.08 ms | Time (FPGA):   259.38 ms
# [이미지 #212] Time (CPU):  3308.26 ms | Time (FPGA):   257.56 ms
# [이미지 #213] Time (CPU):  3305.03 ms | Time (FPGA):   257.60 ms
# [이미지 #214] Time (CPU):  3307.97 ms | Time (FPGA):   257.68 ms
# [이미지 #215] Time (CPU):  3304.98 ms | Time (FPGA):   257.57 ms
# [이미지 #216] Time (CPU):  3306.87 ms | Time (FPGA):   260.09 ms
# [이미지 #217] Time (CPU):  3308.32 ms | Time (FPGA):   258.03 ms
# [이미지 #218] Time (CPU):  3307.66 ms | Time (FPGA):   257.72 ms
# [이미지 #219] Time (CPU):  3304.92 ms | Time (FPGA):   257.90 ms
# [이미지 #220] Time (CPU):  3308.15 ms | Time (FPGA):   257.86 ms
# [이미지 #221] Time (CPU):  3305.99 ms | Time (FPGA):   260.39 ms
# [이미지 #222] Time (CPU):  3305.92 ms | Time (FPGA):   259.13 ms
# [이미지 #223] Time (CPU):  3307.27 ms | Time (FPGA):   259.48 ms
# [이미지 #224] Time (CPU):  3307.00 ms | Time (FPGA):   259.31 ms
# [이미지 #225] Time (CPU):  3306.88 ms | Time (FPGA):   259.26 ms
# [이미지 #226] Time (CPU):  3317.05 ms | Time (FPGA):   258.20 ms
# [이미지 #227] Time (CPU):  3323.24 ms | Time (FPGA):   345.89 ms
# [이미지 #228] Time (CPU):  3311.02 ms | Time (FPGA):   259.02 ms
# [이미지 #229] Time (CPU):  3308.22 ms | Time (FPGA):   259.02 ms
# [이미지 #230] Time (CPU):  3311.96 ms | Time (FPGA):   260.33 ms
# [이미지 #231] Time (CPU):  3309.93 ms | Time (FPGA):   259.97 ms
# [이미지 #232] Time (CPU):  3313.57 ms | Time (FPGA):   259.71 ms
# [이미지 #233] Time (CPU):  3311.66 ms | Time (FPGA):   259.94 ms
# [이미지 #234] Time (CPU):  3319.41 ms | Time (FPGA):   257.75 ms
# [이미지 #235] Time (CPU):  3310.41 ms | Time (FPGA):   257.70 ms
# [이미지 #236] Time (CPU):  3308.56 ms | Time (FPGA):   258.32 ms
# [이미지 #237] Time (CPU):  3308.74 ms | Time (FPGA):   257.78 ms
# [이미지 #238] Time (CPU):  3310.56 ms | Time (FPGA):   259.48 ms
# [이미지 #239] Time (CPU):  3312.08 ms | Time (FPGA):   259.79 ms
# [이미지 #240] Time (CPU):  3309.29 ms | Time (FPGA):   257.93 ms
# [이미지 #241] Time (CPU):  3307.26 ms | Time (FPGA):   258.92 ms
# [이미지 #242] Time (CPU):  3308.39 ms | Time (FPGA):   264.63 ms
# [이미지 #243] Time (CPU):  3309.13 ms | Time (FPGA):   257.81 ms
# [이미지 #244] Time (CPU):  3308.69 ms | Time (FPGA):   258.81 ms
# [이미지 #245] Time (CPU):  3314.63 ms | Time (FPGA):   258.10 ms
# [이미지 #246] Time (CPU):  3310.26 ms | Time (FPGA):   257.86 ms
# [이미지 #247] Time (CPU):  3309.56 ms | Time (FPGA):   257.71 ms
# [이미지 #248] Time (CPU):  3308.23 ms | Time (FPGA):   257.90 ms
# [이미지 #249] Time (CPU):  3308.39 ms | Time (FPGA):   257.59 ms
# [이미지 #250] Time (CPU):  3309.82 ms | Time (FPGA):   260.21 ms
# [이미지 #251] Time (CPU):  3317.11 ms | Time (FPGA):   262.23 ms
# [이미지 #252] Time (CPU):  3308.64 ms | Time (FPGA):   262.01 ms
# [이미지 #253] Time (CPU):  3317.49 ms | Time (FPGA):   258.96 ms
# [이미지 #254] Time (CPU):  3317.58 ms | Time (FPGA):   265.13 ms
# [이미지 #255] Time (CPU):  3309.16 ms | Time (FPGA):   261.90 ms
# [이미지 #256] Time (CPU):  3315.15 ms | Time (FPGA):   258.67 ms
# [이미지 #257] Time (CPU):  3312.72 ms | Time (FPGA):   262.85 ms
# [이미지 #258] Time (CPU):  3314.11 ms | Time (FPGA):   258.96 ms
# [이미지 #259] Time (CPU):  3320.72 ms | Time (FPGA):   261.97 ms
# [이미지 #260] Time (CPU):  3319.73 ms | Time (FPGA):   258.96 ms
# [이미지 #261] Time (CPU):  3330.74 ms | Time (FPGA):   262.03 ms
# [이미지 #262] Time (CPU):  3311.72 ms | Time (FPGA):   261.32 ms
# [이미지 #263] Time (CPU):  3311.22 ms | Time (FPGA):   261.76 ms
# [이미지 #264] Time (CPU):  3309.76 ms | Time (FPGA):   262.49 ms
# [이미지 #265] Time (CPU):  3312.88 ms | Time (FPGA):   261.49 ms
# [이미지 #266] Time (CPU):  3309.76 ms | Time (FPGA):   262.12 ms
# [이미지 #267] Time (CPU):  3313.06 ms | Time (FPGA):   262.16 ms
# [이미지 #268] Time (CPU):  3316.14 ms | Time (FPGA):   261.77 ms
# [이미지 #269] Time (CPU):  3312.33 ms | Time (FPGA):   262.00 ms
# [이미지 #270] Time (CPU):  3315.16 ms | Time (FPGA):   261.44 ms
# [이미지 #271] Time (CPU):  3313.42 ms | Time (FPGA):   259.84 ms
# [이미지 #272] Time (CPU):  3310.05 ms | Time (FPGA):   259.00 ms
# [이미지 #273] Time (CPU):  3312.95 ms | Time (FPGA):   258.63 ms
# [이미지 #274] Time (CPU):  3312.26 ms | Time (FPGA):   258.86 ms
# [이미지 #275] Time (CPU):  3310.39 ms | Time (FPGA):   258.72 ms
# [이미지 #276] Time (CPU):  3311.23 ms | Time (FPGA):   258.68 ms
# [이미지 #277] Time (CPU):  3312.55 ms | Time (FPGA):   258.48 ms
# [이미지 #278] Time (CPU):  3310.47 ms | Time (FPGA):   258.56 ms
# [이미지 #279] Time (CPU):  3311.28 ms | Time (FPGA):   258.35 ms
# [이미지 #280] Time (CPU):  3311.94 ms | Time (FPGA):   258.90 ms
# [이미지 #281] Time (CPU):  3309.91 ms | Time (FPGA):   260.08 ms
# [이미지 #282] Time (CPU):  3316.32 ms | Time (FPGA):   260.47 ms
# [이미지 #283] Time (CPU):  3312.61 ms | Time (FPGA):   258.45 ms
# [이미지 #284] Time (CPU):  3314.15 ms | Time (FPGA):   260.46 ms
# [이미지 #285] Time (CPU):  3319.18 ms | Time (FPGA):   257.96 ms
# [이미지 #286] Time (CPU):  3310.68 ms | Time (FPGA):   257.76 ms
# [이미지 #287] Time (CPU):  3313.96 ms | Time (FPGA):   258.26 ms
# [이미지 #288] Time (CPU):  3311.58 ms | Time (FPGA):   258.33 ms
# [이미지 #289] Time (CPU):  3312.82 ms | Time (FPGA):   258.16 ms
# [이미지 #290] Time (CPU):  3311.42 ms | Time (FPGA):   257.98 ms
# [이미지 #291] Time (CPU):  3311.21 ms | Time (FPGA):   263.70 ms
# [이미지 #292] Time (CPU):  3313.30 ms | Time (FPGA):   262.12 ms
# [이미지 #293] Time (CPU):  3316.14 ms | Time (FPGA):   262.29 ms
# [이미지 #294] Time (CPU):  3317.77 ms | Time (FPGA):   262.04 ms
# [이미지 #295] Time (CPU):  3313.01 ms | Time (FPGA):   262.05 ms
# [이미지 #296] Time (CPU):  3312.17 ms | Time (FPGA):   262.53 ms
# [이미지 #297] Time (CPU):  3315.10 ms | Time (FPGA):   262.77 ms
# [이미지 #298] Time (CPU):  3311.84 ms | Time (FPGA):   262.17 ms
# [이미지 #299] Time (CPU):  3312.12 ms | Time (FPGA):   261.98 ms
# [이미지 #300] Time (CPU):  3311.92 ms | Time (FPGA):   262.03 ms
# [이미지 #301] Time (CPU):  3313.59 ms | Time (FPGA):   262.87 ms
# [이미지 #302] Time (CPU):  3311.00 ms | Time (FPGA):   262.98 ms
# [이미지 #303] Time (CPU):  3314.67 ms | Time (FPGA):   261.75 ms
# [이미지 #304] Time (CPU):  3318.89 ms | Time (FPGA):   262.19 ms
# [이미지 #305] Time (CPU):  3321.55 ms | Time (FPGA):   259.33 ms
# [이미지 #306] Time (CPU):  3324.38 ms | Time (FPGA):   263.61 ms
# [이미지 #307] Time (CPU):  3315.19 ms | Time (FPGA):   264.56 ms
# [이미지 #308] Time (CPU):  3315.91 ms | Time (FPGA):   259.31 ms
# [이미지 #309] Time (CPU):  3316.10 ms | Time (FPGA):   263.57 ms
# [이미지 #310] Time (CPU):  3314.79 ms | Time (FPGA):   262.05 ms
# [이미지 #311] Time (CPU):  3313.14 ms | Time (FPGA):   262.64 ms
# [이미지 #312] Time (CPU):  3350.91 ms | Time (FPGA):   262.21 ms
# [이미지 #313] Time (CPU):  3315.07 ms | Time (FPGA):   263.98 ms
# [이미지 #314] Time (CPU):  3312.51 ms | Time (FPGA):   262.52 ms
# [이미지 #315] Time (CPU):  3314.04 ms | Time (FPGA):   258.74 ms
# [이미지 #316] Time (CPU):  3314.27 ms | Time (FPGA):   263.21 ms
# [이미지 #317] Time (CPU):  3313.76 ms | Time (FPGA):   260.60 ms
# [이미지 #318] Time (CPU):  3324.44 ms | Time (FPGA):   263.65 ms
# [이미지 #319] Time (CPU):  3315.45 ms | Time (FPGA):   262.98 ms
# [이미지 #320] Time (CPU):  3314.71 ms | Time (FPGA):   263.40 ms
# [이미지 #321] Time (CPU):  3318.73 ms | Time (FPGA):   259.51 ms
# [이미지 #322] Time (CPU):  3313.06 ms | Time (FPGA):   260.09 ms
# [이미지 #323] Time (CPU):  3310.88 ms | Time (FPGA):   259.95 ms
# [이미지 #324] Time (CPU):  3312.13 ms | Time (FPGA):   259.80 ms
# [이미지 #325] Time (CPU):  3311.93 ms | Time (FPGA):   258.65 ms
# [이미지 #326] Time (CPU):  3314.78 ms | Time (FPGA):   258.88 ms
# [이미지 #327] Time (CPU):  3341.36 ms | Time (FPGA):   334.59 ms
# [이미지 #328] Time (CPU):  3317.29 ms | Time (FPGA):   258.37 ms
# [이미지 #329] Time (CPU):  3311.59 ms | Time (FPGA):   258.31 ms
# [이미지 #330] Time (CPU):  3313.03 ms | Time (FPGA):   258.23 ms
# [이미지 #331] Time (CPU):  3313.41 ms | Time (FPGA):   260.33 ms
# [이미지 #332] Time (CPU):  3313.46 ms | Time (FPGA):   259.91 ms
# [이미지 #333] Time (CPU):  3314.97 ms | Time (FPGA):   261.96 ms
# [이미지 #334] Time (CPU):  3319.06 ms | Time (FPGA):   258.30 ms
# [이미지 #335] Time (CPU):  3318.55 ms | Time (FPGA):   259.19 ms
# [이미지 #336] Time (CPU):  3313.87 ms | Time (FPGA):   259.13 ms
# [이미지 #337] Time (CPU):  3313.96 ms | Time (FPGA):   258.17 ms
# [이미지 #338] Time (CPU):  3312.97 ms | Time (FPGA):   258.06 ms
# [이미지 #339] Time (CPU):  3312.32 ms | Time (FPGA):   258.35 ms
# [이미지 #340] Time (CPU):  3313.24 ms | Time (FPGA):   258.25 ms
# [이미지 #341] Time (CPU):  3309.67 ms | Time (FPGA):   260.04 ms
# [이미지 #342] Time (CPU):  3311.31 ms | Time (FPGA):   259.31 ms
# [이미지 #343] Time (CPU):  3315.77 ms | Time (FPGA):   260.01 ms
# [이미지 #344] Time (CPU):  3310.58 ms | Time (FPGA):   259.72 ms
# [이미지 #345] Time (CPU):  3310.21 ms | Time (FPGA):   258.69 ms
# [이미지 #346] Time (CPU):  3314.55 ms | Time (FPGA):   260.57 ms
# [이미지 #347] Time (CPU):  3307.77 ms | Time (FPGA):   258.25 ms
# [이미지 #348] Time (CPU):  3311.93 ms | Time (FPGA):   260.39 ms
# [이미지 #349] Time (CPU):  3312.88 ms | Time (FPGA):   259.20 ms
# [이미지 #350] Time (CPU):  3315.79 ms | Time (FPGA):   261.35 ms
# [이미지 #351] Time (CPU):  3310.66 ms | Time (FPGA):   261.87 ms
# [이미지 #352] Time (CPU):  3323.53 ms | Time (FPGA):   262.42 ms
# [이미지 #353] Time (CPU):  3321.76 ms | Time (FPGA):   258.43 ms
# [이미지 #354] Time (CPU):  3316.65 ms | Time (FPGA):   262.16 ms
# [이미지 #355] Time (CPU):  3319.52 ms | Time (FPGA):   259.88 ms
# [이미지 #356] Time (CPU):  3316.93 ms | Time (FPGA):   263.10 ms
# [이미지 #357] Time (CPU):  3316.68 ms | Time (FPGA):   265.76 ms
# [이미지 #358] Time (CPU):  3316.36 ms | Time (FPGA):   260.20 ms
# [이미지 #359] Time (CPU):  3310.95 ms | Time (FPGA):   260.25 ms
# [이미지 #360] Time (CPU):  3322.79 ms | Time (FPGA):   262.71 ms
# [이미지 #361] Time (CPU):  3361.65 ms | Time (FPGA):   263.54 ms
# [이미지 #362] Time (CPU):  3317.11 ms | Time (FPGA):   260.11 ms
# [이미지 #363] Time (CPU):  3315.99 ms | Time (FPGA):   259.95 ms
# [이미지 #364] Time (CPU):  3317.97 ms | Time (FPGA):   262.93 ms
# [이미지 #365] Time (CPU):  3315.01 ms | Time (FPGA):   258.99 ms
# [이미지 #366] Time (CPU):  3314.97 ms | Time (FPGA):   259.07 ms
# [이미지 #367] Time (CPU):  3313.40 ms | Time (FPGA):   258.80 ms
# [이미지 #368] Time (CPU):  3313.68 ms | Time (FPGA):   267.47 ms
# [이미지 #369] Time (CPU):  3318.30 ms | Time (FPGA):   260.49 ms
# [이미지 #370] Time (CPU):  3317.36 ms | Time (FPGA):   258.44 ms
# [이미지 #371] Time (CPU):  3311.65 ms | Time (FPGA):   259.40 ms
# [이미지 #372] Time (CPU):  3312.92 ms | Time (FPGA):   258.51 ms
# [이미지 #373] Time (CPU):  3313.34 ms | Time (FPGA):   258.32 ms
# [이미지 #374] Time (CPU):  3319.20 ms | Time (FPGA):   260.76 ms
# [이미지 #375] Time (CPU):  3312.99 ms | Time (FPGA):   258.29 ms
# [이미지 #376] Time (CPU):  3313.27 ms | Time (FPGA):   258.59 ms
# [이미지 #377] Time (CPU):  3322.75 ms | Time (FPGA):   258.96 ms
# [이미지 #378] Time (CPU):  3315.99 ms | Time (FPGA):   258.63 ms
# [이미지 #379] Time (CPU):  3313.75 ms | Time (FPGA):   258.22 ms
# [이미지 #380] Time (CPU):  3313.30 ms | Time (FPGA):   258.10 ms
# [이미지 #381] Time (CPU):  3316.05 ms | Time (FPGA):   263.12 ms
# [이미지 #382] Time (CPU):  3318.35 ms | Time (FPGA):   262.39 ms
# [이미지 #383] Time (CPU):  3317.18 ms | Time (FPGA):   261.93 ms
# [이미지 #384] Time (CPU):  3319.24 ms | Time (FPGA):   259.90 ms
# [이미지 #385] Time (CPU):  3323.70 ms | Time (FPGA):   258.47 ms
# [이미지 #386] Time (CPU):  3316.91 ms | Time (FPGA):   265.34 ms
# [이미지 #387] Time (CPU):  3315.12 ms | Time (FPGA):   263.00 ms
# [이미지 #388] Time (CPU):  3316.62 ms | Time (FPGA):   263.17 ms
# [이미지 #389] Time (CPU):  3318.24 ms | Time (FPGA):   260.12 ms
# [이미지 #390] Time (CPU):  3321.43 ms | Time (FPGA):   263.01 ms
# [이미지 #391] Time (CPU):  3316.55 ms | Time (FPGA):   262.45 ms
# [이미지 #392] Time (CPU):  3317.21 ms | Time (FPGA):   265.83 ms
# [이미지 #393] Time (CPU):  3320.80 ms | Time (FPGA):   261.68 ms
# [이미지 #394] Time (CPU):  3347.16 ms | Time (FPGA):   264.15 ms
# [이미지 #395] Time (CPU):  3322.13 ms | Time (FPGA):   261.40 ms
# [이미지 #396] Time (CPU):  3322.12 ms | Time (FPGA):   263.20 ms
# [이미지 #397] Time (CPU):  3328.37 ms | Time (FPGA):   261.24 ms
# [이미지 #398] Time (CPU):  3328.32 ms | Time (FPGA):   263.59 ms
# [이미지 #399] Time (CPU):  3323.07 ms | Time (FPGA):   266.21 ms
# [이미지 #400] Time (CPU):  3325.22 ms | Time (FPGA):   261.17 ms
# [이미지 #401] Time (CPU):  3321.62 ms | Time (FPGA):   263.38 ms
# [이미지 #402] Time (CPU):  3331.00 ms | Time (FPGA):   263.53 ms
# [이미지 #403] Time (CPU):  3312.42 ms | Time (FPGA):   266.13 ms
# [이미지 #404] Time (CPU):  3320.31 ms | Time (FPGA):   261.92 ms
# [이미지 #405] Time (CPU):  3323.84 ms | Time (FPGA):   263.29 ms
# [이미지 #406] Time (CPU):  3320.44 ms | Time (FPGA):   262.61 ms
# [이미지 #407] Time (CPU):  3317.14 ms | Time (FPGA):   262.41 ms
# [이미지 #408] Time (CPU):  3315.01 ms | Time (FPGA):   262.44 ms
# [이미지 #409] Time (CPU):  3320.95 ms | Time (FPGA):   259.03 ms
# [이미지 #410] Time (CPU):  3322.58 ms | Time (FPGA):   298.43 ms
# [이미지 #411] Time (CPU):  3322.85 ms | Time (FPGA):   262.48 ms
# [이미지 #412] Time (CPU):  3321.07 ms | Time (FPGA):   262.92 ms
# [이미지 #413] Time (CPU):  3320.84 ms | Time (FPGA):   260.73 ms
# [이미지 #414] Time (CPU):  3318.98 ms | Time (FPGA):   263.39 ms
# [이미지 #415] Time (CPU):  3325.95 ms | Time (FPGA):   259.08 ms
# [이미지 #416] Time (CPU):  3321.78 ms | Time (FPGA):   262.19 ms
# [이미지 #417] Time (CPU):  3315.69 ms | Time (FPGA):   263.16 ms
# [이미지 #418] Time (CPU):  3318.03 ms | Time (FPGA):   262.24 ms
# [이미지 #419] Time (CPU):  3328.01 ms | Time (FPGA):   263.11 ms
# [이미지 #420] Time (CPU):  3322.79 ms | Time (FPGA):   262.36 ms
# [이미지 #421] Time (CPU):  3316.71 ms | Time (FPGA):   262.21 ms
# [이미지 #422] Time (CPU):  3320.29 ms | Time (FPGA):   260.21 ms
# [이미지 #423] Time (CPU):  3318.71 ms | Time (FPGA):   263.36 ms
# [이미지 #424] Time (CPU):  3318.15 ms | Time (FPGA):   262.04 ms
# [이미지 #425] Time (CPU):  3326.09 ms | Time (FPGA):   260.40 ms
# [이미지 #426] Time (CPU):  3330.89 ms | Time (FPGA):   266.72 ms
# [이미지 #427] Time (CPU):  3338.38 ms | Time (FPGA):   260.13 ms
# [이미지 #428] Time (CPU):  3324.04 ms | Time (FPGA):   262.69 ms
# [이미지 #429] Time (CPU):  3321.52 ms | Time (FPGA):   260.51 ms
# [이미지 #430] Time (CPU):  3320.40 ms | Time (FPGA):   263.33 ms
# [이미지 #431] Time (CPU):  3318.50 ms | Time (FPGA):   260.26 ms
# [이미지 #432] Time (CPU):  3316.44 ms | Time (FPGA):   258.32 ms
# [이미지 #433] Time (CPU):  3316.37 ms | Time (FPGA):   258.70 ms
# [이미지 #434] Time (CPU):  3323.08 ms | Time (FPGA):   263.61 ms
# [이미지 #435] Time (CPU):  3317.61 ms | Time (FPGA):   262.58 ms
# [이미지 #436] Time (CPU):  3326.13 ms | Time (FPGA):   263.40 ms
# [이미지 #437] Time (CPU):  3316.61 ms | Time (FPGA):   263.14 ms
# [이미지 #438] Time (CPU):  3318.44 ms | Time (FPGA):   258.95 ms
# [이미지 #439] Time (CPU):  3320.32 ms | Time (FPGA):   262.66 ms
# [이미지 #440] Time (CPU):  3317.51 ms | Time (FPGA):   262.57 ms
# [이미지 #441] Time (CPU):  3326.86 ms | Time (FPGA):   262.90 ms
# [이미지 #442] Time (CPU):  3317.88 ms | Time (FPGA):   262.58 ms
# [이미지 #443] Time (CPU):  3321.36 ms | Time (FPGA):   259.09 ms
# [이미지 #444] Time (CPU):  3326.96 ms | Time (FPGA):   263.27 ms
# [이미지 #445] Time (CPU):  3323.64 ms | Time (FPGA):   264.01 ms
# [이미지 #446] Time (CPU):  3322.04 ms | Time (FPGA):   261.97 ms
# [이미지 #447] Time (CPU):  3324.14 ms | Time (FPGA):   262.57 ms
# [이미지 #448] Time (CPU):  3317.61 ms | Time (FPGA):   262.18 ms
# [이미지 #449] Time (CPU):  3320.73 ms | Time (FPGA):   260.06 ms
# [이미지 #450] Time (CPU):  3326.20 ms | Time (FPGA):   266.88 ms
# [이미지 #451] Time (CPU):  3322.25 ms | Time (FPGA):   259.45 ms
# [이미지 #452] Time (CPU):  3321.81 ms | Time (FPGA):   258.51 ms
# [이미지 #453] Time (CPU):  3320.19 ms | Time (FPGA):   260.14 ms
# [이미지 #454] Time (CPU):  3316.73 ms | Time (FPGA):   258.79 ms
# [이미지 #455] Time (CPU):  3317.15 ms | Time (FPGA):   259.02 ms
# [이미지 #456] Time (CPU):  3314.95 ms | Time (FPGA):   260.36 ms
# [이미지 #457] Time (CPU):  3316.73 ms | Time (FPGA):   260.19 ms
# [이미지 #458] Time (CPU):  3315.70 ms | Time (FPGA):   261.22 ms
# [이미지 #459] Time (CPU):  3315.28 ms | Time (FPGA):   259.91 ms
# [이미지 #460] Time (CPU):  3314.94 ms | Time (FPGA):   260.50 ms
# [이미지 #461] Time (CPU):  3317.87 ms | Time (FPGA):   261.59 ms
# [이미지 #462] Time (CPU):  3319.78 ms | Time (FPGA):   258.57 ms
# [이미지 #463] Time (CPU):  3318.49 ms | Time (FPGA):   258.31 ms
# [이미지 #464] Time (CPU):  3318.88 ms | Time (FPGA):   260.50 ms
# [이미지 #465] Time (CPU):  3314.88 ms | Time (FPGA):   257.67 ms
# [이미지 #466] Time (CPU):  3316.28 ms | Time (FPGA):   257.93 ms
# [이미지 #467] Time (CPU):  3314.49 ms | Time (FPGA):   258.81 ms
# [이미지 #468] Time (CPU):  3315.36 ms | Time (FPGA):   258.20 ms
# [이미지 #469] Time (CPU):  3318.06 ms | Time (FPGA):   258.31 ms
# [이미지 #470] Time (CPU):  3316.39 ms | Time (FPGA):   258.17 ms
# [이미지 #471] Time (CPU):  3317.48 ms | Time (FPGA):   258.46 ms
# [이미지 #472] Time (CPU):  3315.16 ms | Time (FPGA):   261.21 ms
# [이미지 #473] Time (CPU):  3314.52 ms | Time (FPGA):   261.36 ms
# [이미지 #474] Time (CPU):  3318.85 ms | Time (FPGA):   258.65 ms
# [이미지 #475] Time (CPU):  3317.84 ms | Time (FPGA):   259.90 ms
# [이미지 #476] Time (CPU):  3319.97 ms | Time (FPGA):   258.30 ms
# [이미지 #477] Time (CPU):  3314.65 ms | Time (FPGA):   258.06 ms
# [이미지 #478] Time (CPU):  3320.41 ms | Time (FPGA):   262.00 ms
# [이미지 #479] Time (CPU):  3317.51 ms | Time (FPGA):   258.72 ms
# [이미지 #480] Time (CPU):  3315.46 ms | Time (FPGA):   258.53 ms
# [이미지 #481] Time (CPU):  3316.67 ms | Time (FPGA):   262.03 ms
# [이미지 #482] Time (CPU):  3318.76 ms | Time (FPGA):   262.25 ms
# [이미지 #483] Time (CPU):  3318.93 ms | Time (FPGA):   264.15 ms
# [이미지 #484] Time (CPU):  3316.42 ms | Time (FPGA):   262.28 ms
# [이미지 #485] Time (CPU):  3314.06 ms | Time (FPGA):   264.45 ms
# [이미지 #486] Time (CPU):  3317.23 ms | Time (FPGA):   262.87 ms
# [이미지 #487] Time (CPU):  3312.37 ms | Time (FPGA):   258.11 ms
# [이미지 #488] Time (CPU):  3312.00 ms | Time (FPGA):   260.38 ms
# [이미지 #489] Time (CPU):  3314.78 ms | Time (FPGA):   259.40 ms
# [이미지 #490] Time (CPU):  3314.09 ms | Time (FPGA):   260.38 ms
# [이미지 #491] Time (CPU):  3311.96 ms | Time (FPGA):   258.16 ms
# [이미지 #492] Time (CPU):  3311.88 ms | Time (FPGA):   258.14 ms
# [이미지 #493] Time (CPU):  3316.37 ms | Time (FPGA):   260.68 ms
# [이미지 #494] Time (CPU):  3333.31 ms | Time (FPGA):   259.34 ms
# [이미지 #495] Time (CPU):  3311.90 ms | Time (FPGA):   259.03 ms
# [이미지 #496] Time (CPU):  3311.11 ms | Time (FPGA):   258.80 ms
# [이미지 #497] Time (CPU):  3312.27 ms | Time (FPGA):   258.27 ms
# [이미지 #498] Time (CPU):  3312.19 ms | Time (FPGA):   258.48 ms
# [이미지 #499] Time (CPU):  3312.26 ms | Time (FPGA):   258.35 ms
# [이미지 #500] Time (CPU):  3311.03 ms | Time (FPGA):   258.69 ms
# [이미지 #501] Time (CPU):  3315.32 ms | Time (FPGA):   262.60 ms
# [이미지 #502] Time (CPU):  3313.25 ms | Time (FPGA):   261.69 ms
# [이미지 #503] Time (CPU):  3328.26 ms | Time (FPGA):   261.52 ms
# [이미지 #504] Time (CPU):  3312.68 ms | Time (FPGA):   262.03 ms
# [이미지 #505] Time (CPU):  3316.81 ms | Time (FPGA):   264.70 ms
# [이미지 #506] Time (CPU):  3315.31 ms | Time (FPGA):   262.89 ms
# [이미지 #507] Time (CPU):  3318.75 ms | Time (FPGA):   261.34 ms
# [이미지 #508] Time (CPU):  3312.74 ms | Time (FPGA):   261.84 ms
# [이미지 #509] Time (CPU):  3318.92 ms | Time (FPGA):   261.90 ms
# [이미지 #510] Time (CPU):  3311.97 ms | Time (FPGA):   263.54 ms
# [이미지 #511] Time (CPU):  3322.72 ms | Time (FPGA):   262.14 ms
# [이미지 #512] Time (CPU):  3313.75 ms | Time (FPGA):   261.92 ms
# [이미지 #513] Time (CPU):  3321.70 ms | Time (FPGA):   261.68 ms
# [이미지 #514] Time (CPU):  3315.06 ms | Time (FPGA):   264.52 ms
# [이미지 #515] Time (CPU):  3321.13 ms | Time (FPGA):   262.10 ms
# [이미지 #516] Time (CPU):  3313.27 ms | Time (FPGA):   262.77 ms
# [이미지 #517] Time (CPU):  3318.06 ms | Time (FPGA):   262.05 ms
# [이미지 #518] Time (CPU):  3312.94 ms | Time (FPGA):   263.13 ms
# [이미지 #519] Time (CPU):  3321.52 ms | Time (FPGA):   261.85 ms
# [이미지 #520] Time (CPU):  3314.07 ms | Time (FPGA):   264.18 ms
# [이미지 #521] Time (CPU):  3322.62 ms | Time (FPGA):   261.71 ms
# [이미지 #522] Time (CPU):  3313.65 ms | Time (FPGA):   260.91 ms
# [이미지 #523] Time (CPU):  3318.00 ms | Time (FPGA):   260.50 ms
# [이미지 #524] Time (CPU):  3312.29 ms | Time (FPGA):   259.85 ms
# [이미지 #525] Time (CPU):  3318.21 ms | Time (FPGA):   260.90 ms
# [이미지 #526] Time (CPU):  3312.01 ms | Time (FPGA):   260.11 ms
# [이미지 #527] Time (CPU):  3336.00 ms | Time (FPGA):   258.69 ms
# [이미지 #528] Time (CPU):  3322.53 ms | Time (FPGA):   258.72 ms
# [이미지 #529] Time (CPU):  3318.15 ms | Time (FPGA):   258.86 ms
# [이미지 #530] Time (CPU):  3313.15 ms | Time (FPGA):   259.66 ms
# [이미지 #531] Time (CPU):  3317.04 ms | Time (FPGA):   259.12 ms
# [이미지 #532] Time (CPU):  3312.90 ms | Time (FPGA):   259.23 ms
# [이미지 #533] Time (CPU):  3318.03 ms | Time (FPGA):   258.45 ms
# [이미지 #534] Time (CPU):  3317.29 ms | Time (FPGA):   261.48 ms
# [이미지 #535] Time (CPU):  3317.95 ms | Time (FPGA):   260.08 ms
# [이미지 #536] Time (CPU):  3314.38 ms | Time (FPGA):   259.91 ms
# [이미지 #537] Time (CPU):  3317.86 ms | Time (FPGA):   260.73 ms
# [이미지 #538] Time (CPU):  3317.42 ms | Time (FPGA):   258.23 ms
# [이미지 #539] Time (CPU):  3319.94 ms | Time (FPGA):   259.60 ms
# [이미지 #540] Time (CPU):  3311.60 ms | Time (FPGA):   260.75 ms
# [이미지 #541] Time (CPU):  3316.78 ms | Time (FPGA):   258.27 ms
# [이미지 #542] Time (CPU):  3316.86 ms | Time (FPGA):   258.15 ms
# [이미지 #543] Time (CPU):  3317.36 ms | Time (FPGA):   258.51 ms
# [이미지 #544] Time (CPU):  3316.87 ms | Time (FPGA):   262.07 ms
# [이미지 #545] Time (CPU):  3319.27 ms | Time (FPGA):   259.04 ms
# [이미지 #546] Time (CPU):  3316.04 ms | Time (FPGA):   258.17 ms
# [이미지 #547] Time (CPU):  3317.67 ms | Time (FPGA):   258.58 ms
# [이미지 #548] Time (CPU):  3317.60 ms | Time (FPGA):   257.99 ms
# [이미지 #549] Time (CPU):  3320.21 ms | Time (FPGA):   258.34 ms
# [이미지 #550] Time (CPU):  3319.24 ms | Time (FPGA):   258.72 ms
# [이미지 #551] Time (CPU):  3319.06 ms | Time (FPGA):   261.98 ms
# [이미지 #552] Time (CPU):  3319.71 ms | Time (FPGA):   266.06 ms
# [이미지 #553] Time (CPU):  3325.16 ms | Time (FPGA):   262.60 ms
# [이미지 #554] Time (CPU):  3317.07 ms | Time (FPGA):   262.39 ms
# [이미지 #555] Time (CPU):  3318.40 ms | Time (FPGA):   261.65 ms
# [이미지 #556] Time (CPU):  3317.28 ms | Time (FPGA):   262.40 ms
# [이미지 #557] Time (CPU):  3321.58 ms | Time (FPGA):   263.34 ms
# [이미지 #558] Time (CPU):  3317.82 ms | Time (FPGA):   262.67 ms
# [이미지 #559] Time (CPU):  3318.12 ms | Time (FPGA):   262.50 ms
# [이미지 #560] Time (CPU):  3334.41 ms | Time (FPGA):   262.28 ms
# [이미지 #561] Time (CPU):  3323.08 ms | Time (FPGA):   260.60 ms
# [이미지 #562] Time (CPU):  3316.18 ms | Time (FPGA):   259.18 ms
# [이미지 #563] Time (CPU):  3320.86 ms | Time (FPGA):   258.97 ms
# [이미지 #564] Time (CPU):  3322.31 ms | Time (FPGA):   258.98 ms
# [이미지 #565] Time (CPU):  3316.70 ms | Time (FPGA):   258.59 ms
# [이미지 #566] Time (CPU):  3317.84 ms | Time (FPGA):   258.97 ms
# [이미지 #567] Time (CPU):  3317.81 ms | Time (FPGA):   258.69 ms
# [이미지 #568] Time (CPU):  3316.46 ms | Time (FPGA):   258.81 ms
# [이미지 #569] Time (CPU):  3318.87 ms | Time (FPGA):   258.58 ms
# [이미지 #570] Time (CPU):  3324.57 ms | Time (FPGA):   259.07 ms
# [이미지 #571] Time (CPU):  3315.39 ms | Time (FPGA):   259.04 ms
# [이미지 #572] Time (CPU):  3312.34 ms | Time (FPGA):   258.52 ms
# [이미지 #573] Time (CPU):  3311.27 ms | Time (FPGA):   258.72 ms
# [이미지 #574] Time (CPU):  3311.36 ms | Time (FPGA):   258.46 ms
# [이미지 #575] Time (CPU):  3311.27 ms | Time (FPGA):   258.97 ms
# [이미지 #576] Time (CPU):  3310.39 ms | Time (FPGA):   258.72 ms
# [이미지 #577] Time (CPU):  3311.45 ms | Time (FPGA):   258.59 ms
# [이미지 #578] Time (CPU):  3313.71 ms | Time (FPGA):   260.70 ms
# [이미지 #579] Time (CPU):  3311.26 ms | Time (FPGA):   258.64 ms
# [이미지 #580] Time (CPU):  3311.16 ms | Time (FPGA):   259.23 ms
# [이미지 #581] Time (CPU):  3311.74 ms | Time (FPGA):   260.78 ms
# [이미지 #582] Time (CPU):  3311.96 ms | Time (FPGA):   259.97 ms
# [이미지 #583] Time (CPU):  3313.73 ms | Time (FPGA):   260.38 ms
# [이미지 #584] Time (CPU):  3313.04 ms | Time (FPGA):   260.07 ms
# [이미지 #585] Time (CPU):  3319.33 ms | Time (FPGA):   259.28 ms
# [이미지 #586] Time (CPU):  3314.36 ms | Time (FPGA):   265.35 ms
# [이미지 #587] Time (CPU):  3312.44 ms | Time (FPGA):   258.70 ms
# [이미지 #588] Time (CPU):  3311.77 ms | Time (FPGA):   259.18 ms
# [이미지 #589] Time (CPU):  3312.78 ms | Time (FPGA):   258.76 ms
# [이미지 #590] Time (CPU):  3312.53 ms | Time (FPGA):   259.49 ms
# [이미지 #591] Time (CPU):  3311.77 ms | Time (FPGA):   261.29 ms
# [이미지 #592] Time (CPU):  3317.81 ms | Time (FPGA):   262.16 ms
# [이미지 #593] Time (CPU):  3312.03 ms | Time (FPGA):   259.13 ms
# [이미지 #594] Time (CPU):  3342.64 ms | Time (FPGA):   258.66 ms
# [이미지 #595] Time (CPU):  3316.92 ms | Time (FPGA):   258.43 ms
# [이미지 #596] Time (CPU):  3310.95 ms | Time (FPGA):   258.76 ms
# [이미지 #597] Time (CPU):  3312.02 ms | Time (FPGA):   262.77 ms
# [이미지 #598] Time (CPU):  3316.35 ms | Time (FPGA):   259.12 ms
# [이미지 #599] Time (CPU):  3311.92 ms | Time (FPGA):   258.41 ms
# [이미지 #600] Time (CPU):  3313.51 ms | Time (FPGA):   260.66 ms
# [이미지 #601] Time (CPU):  3313.08 ms | Time (FPGA):   261.54 ms
# [이미지 #602] Time (CPU):  3312.11 ms | Time (FPGA):   260.06 ms
# [이미지 #603] Time (CPU):  3311.79 ms | Time (FPGA):   260.83 ms
# [이미지 #604] Time (CPU):  3311.86 ms | Time (FPGA):   262.22 ms
# [이미지 #605] Time (CPU):  3316.78 ms | Time (FPGA):   262.64 ms
# [이미지 #606] Time (CPU):  3308.83 ms | Time (FPGA):   258.85 ms
# [이미지 #607] Time (CPU):  3312.39 ms | Time (FPGA):   258.38 ms
# [이미지 #608] Time (CPU):  3312.09 ms | Time (FPGA):   259.08 ms
# [이미지 #609] Time (CPU):  3314.13 ms | Time (FPGA):   259.62 ms
# [이미지 #610] Time (CPU):  3314.18 ms | Time (FPGA):   260.46 ms
# [이미지 #611] Time (CPU):  3309.30 ms | Time (FPGA):   263.94 ms
# [이미지 #612] Time (CPU):  3319.60 ms | Time (FPGA):   266.00 ms
# [이미지 #613] Time (CPU):  3313.14 ms | Time (FPGA):   265.51 ms
# [이미지 #614] Time (CPU):  3314.55 ms | Time (FPGA):   265.33 ms
# [이미지 #615] Time (CPU):  3312.47 ms | Time (FPGA):   266.19 ms
# [이미지 #616] Time (CPU):  3312.85 ms | Time (FPGA):   265.32 ms
# [이미지 #617] Time (CPU):  3313.04 ms | Time (FPGA):   267.05 ms
# [이미지 #618] Time (CPU):  3316.99 ms | Time (FPGA):   269.30 ms
# [이미지 #619] Time (CPU):  3314.61 ms | Time (FPGA):   266.01 ms
# [이미지 #620] Time (CPU):  3312.39 ms | Time (FPGA):   261.98 ms
# [이미지 #621] Time (CPU):  3314.93 ms | Time (FPGA):   259.93 ms
# [이미지 #622] Time (CPU):  3307.57 ms | Time (FPGA):   258.59 ms
# [이미지 #623] Time (CPU):  3310.94 ms | Time (FPGA):   258.86 ms
# [이미지 #624] Time (CPU):  3318.03 ms | Time (FPGA):   258.47 ms
# [이미지 #625] Time (CPU):  3310.31 ms | Time (FPGA):   260.16 ms
# [이미지 #626] Time (CPU):  3309.98 ms | Time (FPGA):   257.96 ms
# [이미지 #627] Time (CPU):  3321.80 ms | Time (FPGA):   258.53 ms
# [이미지 #628] Time (CPU):  3308.72 ms | Time (FPGA):   259.31 ms
# [이미지 #629] Time (CPU):  3314.62 ms | Time (FPGA):   258.40 ms
# [이미지 #630] Time (CPU):  3310.14 ms | Time (FPGA):   258.30 ms
# [이미지 #631] Time (CPU):  3308.84 ms | Time (FPGA):   262.06 ms
# [이미지 #632] Time (CPU):  3309.11 ms | Time (FPGA):   261.78 ms
# [이미지 #633] Time (CPU):  3310.77 ms | Time (FPGA):   261.90 ms
# [이미지 #634] Time (CPU):  3309.94 ms | Time (FPGA):   261.69 ms
# [이미지 #635] Time (CPU):  3311.98 ms | Time (FPGA):   262.51 ms
# [이미지 #636] Time (CPU):  3313.81 ms | Time (FPGA):   261.46 ms
# [이미지 #637] Time (CPU):  3319.76 ms | Time (FPGA):   262.39 ms
# [이미지 #638] Time (CPU):  3312.53 ms | Time (FPGA):   261.76 ms
# [이미지 #639] Time (CPU):  3313.07 ms | Time (FPGA):   265.04 ms
# [이미지 #640] Time (CPU):  3314.03 ms | Time (FPGA):   263.20 ms
# [이미지 #641] Time (CPU):  3316.87 ms | Time (FPGA):   259.64 ms
# [이미지 #642] Time (CPU):  3312.14 ms | Time (FPGA):   259.14 ms
# [이미지 #643] Time (CPU):  3314.47 ms | Time (FPGA):   263.77 ms
# [이미지 #644] Time (CPU):  3312.60 ms | Time (FPGA):   259.77 ms
# [이미지 #645] Time (CPU):  3318.88 ms | Time (FPGA):   258.49 ms
# [이미지 #646] Time (CPU):  3312.16 ms | Time (FPGA):   258.38 ms
# [이미지 #647] Time (CPU):  3312.35 ms | Time (FPGA):   260.64 ms
# [이미지 #648] Time (CPU):  3317.64 ms | Time (FPGA):   260.03 ms
# [이미지 #649] Time (CPU):  3313.94 ms | Time (FPGA):   258.76 ms
# [이미지 #650] Time (CPU):  3311.53 ms | Time (FPGA):   259.85 ms
# [이미지 #651] Time (CPU):  3309.72 ms | Time (FPGA):   258.92 ms
# [이미지 #652] Time (CPU):  3311.53 ms | Time (FPGA):   258.50 ms
# [이미지 #653] Time (CPU):  3310.84 ms | Time (FPGA):   258.53 ms
# [이미지 #654] Time (CPU):  3318.02 ms | Time (FPGA):   258.27 ms
# [이미지 #655] Time (CPU):  3312.23 ms | Time (FPGA):   258.30 ms
# [이미지 #656] Time (CPU):  3309.79 ms | Time (FPGA):   258.90 ms
# [이미지 #657] Time (CPU):  3317.08 ms | Time (FPGA):   258.91 ms
# [이미지 #658] Time (CPU):  3315.07 ms | Time (FPGA):   258.13 ms
# [이미지 #659] Time (CPU):  3315.56 ms | Time (FPGA):   259.03 ms
# [이미지 #660] Time (CPU):  3344.69 ms | Time (FPGA):   259.60 ms
# [이미지 #661] Time (CPU):  3318.73 ms | Time (FPGA):   258.99 ms
# [이미지 #662] Time (CPU):  3317.96 ms | Time (FPGA):   258.47 ms
# [이미지 #663] Time (CPU):  3314.48 ms | Time (FPGA):   259.15 ms
# [이미지 #664] Time (CPU):  3313.47 ms | Time (FPGA):   261.74 ms
# [이미지 #665] Time (CPU):  3311.74 ms | Time (FPGA):   258.46 ms
# [이미지 #666] Time (CPU):  3311.05 ms | Time (FPGA):   258.18 ms
# [이미지 #667] Time (CPU):  3310.47 ms | Time (FPGA):   259.02 ms
# [이미지 #668] Time (CPU):  3316.05 ms | Time (FPGA):   259.32 ms
# [이미지 #669] Time (CPU):  3315.45 ms | Time (FPGA):   260.26 ms
# [이미지 #670] Time (CPU):  3311.67 ms | Time (FPGA):   258.82 ms
# [이미지 #671] Time (CPU):  3315.94 ms | Time (FPGA):   259.15 ms
# [이미지 #672] Time (CPU):  3313.08 ms | Time (FPGA):   258.71 ms
# [이미지 #673] Time (CPU):  3311.57 ms | Time (FPGA):   258.10 ms
# [이미지 #674] Time (CPU):  3312.65 ms | Time (FPGA):   257.93 ms
# [이미지 #675] Time (CPU):  3310.19 ms | Time (FPGA):   257.98 ms
# [이미지 #676] Time (CPU):  3310.67 ms | Time (FPGA):   258.24 ms
# [이미지 #677] Time (CPU):  3312.13 ms | Time (FPGA):   258.22 ms
# [이미지 #678] Time (CPU):  3311.22 ms | Time (FPGA):   259.67 ms
# [이미지 #679] Time (CPU):  3314.42 ms | Time (FPGA):   258.07 ms
# [이미지 #680] Time (CPU):  3312.08 ms | Time (FPGA):   258.52 ms
# [이미지 #681] Time (CPU):  3309.22 ms | Time (FPGA):   259.76 ms
# [이미지 #682] Time (CPU):  3315.31 ms | Time (FPGA):   261.07 ms
# [이미지 #683] Time (CPU):  3317.62 ms | Time (FPGA):   259.61 ms
# [이미지 #684] Time (CPU):  3312.92 ms | Time (FPGA):   260.23 ms
# [이미지 #685] Time (CPU):  3314.15 ms | Time (FPGA):   260.35 ms
# [이미지 #686] Time (CPU):  3313.59 ms | Time (FPGA):   259.24 ms
# [이미지 #687] Time (CPU):  3313.48 ms | Time (FPGA):   259.19 ms
# [이미지 #688] Time (CPU):  3310.79 ms | Time (FPGA):   259.28 ms
# [이미지 #689] Time (CPU):  3318.71 ms | Time (FPGA):   259.14 ms
# [이미지 #690] Time (CPU):  3311.14 ms | Time (FPGA):   259.35 ms
# [이미지 #691] Time (CPU):  3316.33 ms | Time (FPGA):   259.45 ms
# [이미지 #692] Time (CPU):  3314.04 ms | Time (FPGA):   258.73 ms
# [이미지 #693] Time (CPU):  3313.60 ms | Time (FPGA):   259.03 ms
# [이미지 #694] Time (CPU):  3343.73 ms | Time (FPGA):   258.59 ms
# [이미지 #695] Time (CPU):  3316.06 ms | Time (FPGA):   258.49 ms
# [이미지 #696] Time (CPU):  3322.69 ms | Time (FPGA):   260.45 ms
# [이미지 #697] Time (CPU):  3316.29 ms | Time (FPGA):   258.50 ms
# [이미지 #698] Time (CPU):  3313.82 ms | Time (FPGA):   259.88 ms
# [이미지 #699] Time (CPU):  3313.77 ms | Time (FPGA):   258.45 ms
# [이미지 #700] Time (CPU):  3313.91 ms | Time (FPGA):   261.70 ms
# [이미지 #701] Time (CPU):  3317.59 ms | Time (FPGA):   264.55 ms
# [이미지 #702] Time (CPU):  3313.55 ms | Time (FPGA):   263.53 ms
# [이미지 #703] Time (CPU):  3312.51 ms | Time (FPGA):   262.35 ms
# [이미지 #704] Time (CPU):  3314.09 ms | Time (FPGA):   261.64 ms
# [이미지 #705] Time (CPU):  3312.55 ms | Time (FPGA):   262.70 ms
# [이미지 #706] Time (CPU):  3311.47 ms | Time (FPGA):   261.53 ms
# [이미지 #707] Time (CPU):  3312.29 ms | Time (FPGA):   266.15 ms
# [이미지 #708] Time (CPU):  3314.61 ms | Time (FPGA):   266.67 ms
# [이미지 #709] Time (CPU):  3311.57 ms | Time (FPGA):   262.18 ms
# [이미지 #710] Time (CPU):  3313.28 ms | Time (FPGA):   261.74 ms
# [이미지 #711] Time (CPU):  3312.18 ms | Time (FPGA):   262.74 ms
# [이미지 #712] Time (CPU):  3317.43 ms | Time (FPGA):   261.79 ms
# [이미지 #713] Time (CPU):  3320.45 ms | Time (FPGA):   262.27 ms
# [이미지 #714] Time (CPU):  3317.36 ms | Time (FPGA):   261.35 ms
# [이미지 #715] Time (CPU):  3318.84 ms | Time (FPGA):   262.13 ms
# [이미지 #716] Time (CPU):  3313.06 ms | Time (FPGA):   261.58 ms
# [이미지 #717] Time (CPU):  3316.05 ms | Time (FPGA):   261.66 ms
# [이미지 #718] Time (CPU):  3314.52 ms | Time (FPGA):   262.26 ms
# [이미지 #719] Time (CPU):  3315.84 ms | Time (FPGA):   261.34 ms
# [이미지 #720] Time (CPU):  3315.19 ms | Time (FPGA):   262.28 ms
# [이미지 #721] Time (CPU):  3318.21 ms | Time (FPGA):   259.76 ms
# [이미지 #722] Time (CPU):  3310.72 ms | Time (FPGA):   259.60 ms
# [이미지 #723] Time (CPU):  3312.55 ms | Time (FPGA):   259.83 ms
# [이미지 #724] Time (CPU):  3315.84 ms | Time (FPGA):   260.06 ms
# [이미지 #725] Time (CPU):  3313.63 ms | Time (FPGA):   258.33 ms
# [이미지 #726] Time (CPU):  3312.27 ms | Time (FPGA):   258.71 ms
# [이미지 #727] Time (CPU):  3320.81 ms | Time (FPGA):   260.02 ms
# [이미지 #728] Time (CPU):  3313.34 ms | Time (FPGA):   259.03 ms
# [이미지 #729] Time (CPU):  3314.40 ms | Time (FPGA):   259.56 ms
# [이미지 #730] Time (CPU):  3311.16 ms | Time (FPGA):   259.95 ms
# [이미지 #731] Time (CPU):  3315.11 ms | Time (FPGA):   259.56 ms
# [이미지 #732] Time (CPU):  3321.94 ms | Time (FPGA):   262.13 ms
# [이미지 #733] Time (CPU):  3314.94 ms | Time (FPGA):   259.60 ms
# [이미지 #734] Time (CPU):  3316.91 ms | Time (FPGA):   259.51 ms
# [이미지 #735] Time (CPU):  3315.56 ms | Time (FPGA):   258.18 ms
# [이미지 #736] Time (CPU):  3320.26 ms | Time (FPGA):   258.31 ms
# [이미지 #737] Time (CPU):  3313.58 ms | Time (FPGA):   257.64 ms
# [이미지 #738] Time (CPU):  3321.36 ms | Time (FPGA):   257.96 ms
# [이미지 #739] Time (CPU):  3315.33 ms | Time (FPGA):   258.01 ms
# [이미지 #740] Time (CPU):  3319.23 ms | Time (FPGA):   258.15 ms
# [이미지 #741] Time (CPU):  3313.82 ms | Time (FPGA):   259.70 ms
# [이미지 #742] Time (CPU):  3313.76 ms | Time (FPGA):   258.03 ms
# [이미지 #743] Time (CPU):  3316.09 ms | Time (FPGA):   258.46 ms
# [이미지 #744] Time (CPU):  3315.10 ms | Time (FPGA):   259.05 ms
# [이미지 #745] Time (CPU):  3316.70 ms | Time (FPGA):   259.43 ms
# [이미지 #746] Time (CPU):  3316.25 ms | Time (FPGA):   259.28 ms
# [이미지 #747] Time (CPU):  3315.63 ms | Time (FPGA):   258.28 ms
# [이미지 #748] Time (CPU):  3315.75 ms | Time (FPGA):   258.07 ms
# [이미지 #749] Time (CPU):  3315.90 ms | Time (FPGA):   258.21 ms
# [이미지 #750] Time (CPU):  3316.05 ms | Time (FPGA):   257.69 ms
# [이미지 #751] Time (CPU):  3318.14 ms | Time (FPGA):   259.45 ms
# [이미지 #752] Time (CPU):  3312.17 ms | Time (FPGA):   258.76 ms
# [이미지 #753] Time (CPU):  3312.56 ms | Time (FPGA):   260.24 ms
# [이미지 #754] Time (CPU):  3315.25 ms | Time (FPGA):   258.12 ms
# [이미지 #755] Time (CPU):  3317.71 ms | Time (FPGA):   258.00 ms
# [이미지 #756] Time (CPU):  3308.78 ms | Time (FPGA):   258.82 ms
# [이미지 #757] Time (CPU):  3308.59 ms | Time (FPGA):   258.19 ms
# [이미지 #758] Time (CPU):  3315.25 ms | Time (FPGA):   258.41 ms
# [이미지 #759] Time (CPU):  3309.00 ms | Time (FPGA):   258.35 ms
# [이미지 #760] Time (CPU):  3324.39 ms | Time (FPGA):   258.20 ms
# [이미지 #761] Time (CPU):  3310.76 ms | Time (FPGA):   259.21 ms
# [이미지 #762] Time (CPU):  3315.70 ms | Time (FPGA):   258.16 ms
# [이미지 #763] Time (CPU):  3313.58 ms | Time (FPGA):   258.61 ms
# [이미지 #764] Time (CPU):  3310.62 ms | Time (FPGA):   258.18 ms
# [이미지 #765] Time (CPU):  3312.89 ms | Time (FPGA):   260.02 ms
# [이미지 #766] Time (CPU):  3318.17 ms | Time (FPGA):   261.05 ms
# [이미지 #767] Time (CPU):  3310.78 ms | Time (FPGA):   258.57 ms
# [이미지 #768] Time (CPU):  3311.10 ms | Time (FPGA):   258.41 ms
# [이미지 #769] Time (CPU):  3311.78 ms | Time (FPGA):   258.41 ms
# [이미지 #770] Time (CPU):  3317.23 ms | Time (FPGA):   259.41 ms
# [이미지 #771] Time (CPU):  3311.72 ms | Time (FPGA):   259.44 ms
# [이미지 #772] Time (CPU):  3310.12 ms | Time (FPGA):   258.57 ms
# [이미지 #773] Time (CPU):  3310.70 ms | Time (FPGA):   258.32 ms
# [이미지 #774] Time (CPU):  3316.82 ms | Time (FPGA):   258.89 ms
# [이미지 #775] Time (CPU):  3310.86 ms | Time (FPGA):   258.42 ms
# [이미지 #776] Time (CPU):  3310.07 ms | Time (FPGA):   258.42 ms
# [이미지 #777] Time (CPU):  3310.65 ms | Time (FPGA):   258.53 ms
# [이미지 #778] Time (CPU):  3317.20 ms | Time (FPGA):   260.35 ms
# [이미지 #779] Time (CPU):  3310.85 ms | Time (FPGA):   259.02 ms
# [이미지 #780] Time (CPU):  3316.53 ms | Time (FPGA):   259.95 ms
# [이미지 #781] Time (CPU):  3308.22 ms | Time (FPGA):   259.69 ms
# [이미지 #782] Time (CPU):  3315.54 ms | Time (FPGA):   258.36 ms
# [이미지 #783] Time (CPU):  3313.72 ms | Time (FPGA):   258.54 ms
# [이미지 #784] Time (CPU):  3309.48 ms | Time (FPGA):   258.44 ms
# [이미지 #785] Time (CPU):  3310.25 ms | Time (FPGA):   258.98 ms
# [이미지 #786] Time (CPU):  3314.49 ms | Time (FPGA):   258.11 ms
# [이미지 #787] Time (CPU):  3310.26 ms | Time (FPGA):   258.33 ms
# [이미지 #788] Time (CPU):  3311.72 ms | Time (FPGA):   259.62 ms
# [이미지 #789] Time (CPU):  3310.21 ms | Time (FPGA):   259.10 ms
# [이미지 #790] Time (CPU):  3314.10 ms | Time (FPGA):   260.15 ms
# [이미지 #791] Time (CPU):  3310.27 ms | Time (FPGA):   259.53 ms
# [이미지 #792] Time (CPU):  3309.79 ms | Time (FPGA):   259.29 ms
# [이미지 #793] Time (CPU):  3309.34 ms | Time (FPGA):   259.63 ms
# [이미지 #794] Time (CPU):  3336.26 ms | Time (FPGA):   258.50 ms
# [이미지 #795] Time (CPU):  3310.69 ms | Time (FPGA):   261.26 ms
# [이미지 #796] Time (CPU):  3313.05 ms | Time (FPGA):   259.24 ms
# [이미지 #797] Time (CPU):  3318.71 ms | Time (FPGA):   258.23 ms
# [이미지 #798] Time (CPU):  3310.04 ms | Time (FPGA):   259.27 ms
# [이미지 #799] Time (CPU):  3309.22 ms | Time (FPGA):   259.33 ms
# [이미지 #800] Time (CPU):  3314.12 ms | Time (FPGA):   260.51 ms
# [이미지 #801] Time (CPU):  3309.71 ms | Time (FPGA):   258.09 ms
# [이미지 #802] Time (CPU):  3311.25 ms | Time (FPGA):   257.81 ms
# [이미지 #803] Time (CPU):  3310.72 ms | Time (FPGA):   258.25 ms
# [이미지 #804] Time (CPU):  3316.14 ms | Time (FPGA):   262.45 ms
# [이미지 #805] Time (CPU):  3321.06 ms | Time (FPGA):   259.21 ms
# [이미지 #806] Time (CPU):  3311.02 ms | Time (FPGA):   258.98 ms
# [이미지 #807] Time (CPU):  3310.93 ms | Time (FPGA):   259.00 ms
# [이미지 #808] Time (CPU):  3310.26 ms | Time (FPGA):   259.32 ms
# [이미지 #809] Time (CPU):  3315.96 ms | Time (FPGA):   257.91 ms
# [이미지 #810] Time (CPU):  3312.30 ms | Time (FPGA):   258.61 ms
# [이미지 #811] Time (CPU):  3317.42 ms | Time (FPGA):   260.66 ms
# [이미지 #812] Time (CPU):  3314.79 ms | Time (FPGA):   260.94 ms
# [이미지 #813] Time (CPU):  3320.33 ms | Time (FPGA):   259.82 ms
# [이미지 #814] Time (CPU):  3314.18 ms | Time (FPGA):   260.49 ms
# [이미지 #815] Time (CPU):  3314.56 ms | Time (FPGA):   257.91 ms
# [이미지 #816] Time (CPU):  3314.21 ms | Time (FPGA):   259.09 ms
# [이미지 #817] Time (CPU):  3314.20 ms | Time (FPGA):   261.29 ms
# [이미지 #818] Time (CPU):  3311.67 ms | Time (FPGA):   259.12 ms
# [이미지 #819] Time (CPU):  3311.90 ms | Time (FPGA):   258.93 ms
# [이미지 #820] Time (CPU):  3316.40 ms | Time (FPGA):   262.20 ms
# [이미지 #821] Time (CPU):  3312.21 ms | Time (FPGA):   258.16 ms
# [이미지 #822] Time (CPU):  3318.42 ms | Time (FPGA):   258.37 ms
# [이미지 #823] Time (CPU):  3311.50 ms | Time (FPGA):   258.23 ms
# [이미지 #824] Time (CPU):  3311.02 ms | Time (FPGA):   257.83 ms
# [이미지 #825] Time (CPU):  3310.32 ms | Time (FPGA):   258.18 ms
# [이미지 #826] Time (CPU):  3309.43 ms | Time (FPGA):   257.82 ms
# [이미지 #827] Time (CPU):  3324.93 ms | Time (FPGA):   257.88 ms
# [이미지 #828] Time (CPU):  3316.13 ms | Time (FPGA):   258.47 ms
# [이미지 #829] Time (CPU):  3310.86 ms | Time (FPGA):   258.02 ms
# [이미지 #830] Time (CPU):  3313.18 ms | Time (FPGA):   259.57 ms
# [이미지 #831] Time (CPU):  3313.45 ms | Time (FPGA):   262.04 ms
# [이미지 #832] Time (CPU):  3309.72 ms | Time (FPGA):   258.13 ms
# [이미지 #833] Time (CPU):  3310.37 ms | Time (FPGA):   258.27 ms
# [이미지 #834] Time (CPU):  3315.17 ms | Time (FPGA):   260.37 ms
# [이미지 #835] Time (CPU):  3312.51 ms | Time (FPGA):   260.35 ms
# [이미지 #836] Time (CPU):  3311.84 ms | Time (FPGA):   258.38 ms
# [이미지 #837] Time (CPU):  3313.63 ms | Time (FPGA):   264.24 ms
# [이미지 #838] Time (CPU):  3310.85 ms | Time (FPGA):   259.74 ms
# [이미지 #839] Time (CPU):  3323.23 ms | Time (FPGA):   259.06 ms
# [이미지 #840] Time (CPU):  3313.41 ms | Time (FPGA):   258.82 ms
# [이미지 #841] Time (CPU):  3312.27 ms | Time (FPGA):   257.92 ms
# [이미지 #842] Time (CPU):  3313.08 ms | Time (FPGA):   260.52 ms
# [이미지 #843] Time (CPU):  3309.13 ms | Time (FPGA):   258.18 ms
# [이미지 #844] Time (CPU):  3314.51 ms | Time (FPGA):   261.56 ms
# [이미지 #845] Time (CPU):  3311.90 ms | Time (FPGA):   258.75 ms
# [이미지 #846] Time (CPU):  3310.97 ms | Time (FPGA):   257.94 ms
# [이미지 #847] Time (CPU):  3316.46 ms | Time (FPGA):   257.94 ms
# [이미지 #848] Time (CPU):  3312.93 ms | Time (FPGA):   258.26 ms
# [이미지 #849] Time (CPU):  3312.73 ms | Time (FPGA):   258.05 ms
# [이미지 #850] Time (CPU):  3312.17 ms | Time (FPGA):   259.43 ms
# [이미지 #851] Time (CPU):  3315.36 ms | Time (FPGA):   259.03 ms
# [이미지 #852] Time (CPU):  3314.31 ms | Time (FPGA):   258.16 ms
# [이미지 #853] Time (CPU):  3311.94 ms | Time (FPGA):   258.61 ms
# [이미지 #854] Time (CPU):  3311.72 ms | Time (FPGA):   258.18 ms
# [이미지 #855] Time (CPU):  3319.90 ms | Time (FPGA):   260.30 ms
# [이미지 #856] Time (CPU):  3309.44 ms | Time (FPGA):   258.65 ms
# [이미지 #857] Time (CPU):  3310.67 ms | Time (FPGA):   258.23 ms
# [이미지 #858] Time (CPU):  3309.44 ms | Time (FPGA):   258.02 ms
# [이미지 #859] Time (CPU):  3308.26 ms | Time (FPGA):   258.10 ms
# [이미지 #860] Time (CPU):  3323.62 ms | Time (FPGA):   299.73 ms
# [이미지 #861] Time (CPU):  3310.27 ms | Time (FPGA):   259.61 ms
# [이미지 #862] Time (CPU):  3309.33 ms | Time (FPGA):   259.57 ms
# [이미지 #863] Time (CPU):  3309.97 ms | Time (FPGA):   260.20 ms
# [이미지 #864] Time (CPU):  3315.21 ms | Time (FPGA):   259.37 ms
# [이미지 #865] Time (CPU):  3311.37 ms | Time (FPGA):   261.15 ms
# [이미지 #866] Time (CPU):  3312.15 ms | Time (FPGA):   259.59 ms
# [이미지 #867] Time (CPU):  3313.66 ms | Time (FPGA):   259.42 ms
# [이미지 #868] Time (CPU):  3309.56 ms | Time (FPGA):   259.40 ms
# [이미지 #869] Time (CPU):  3310.85 ms | Time (FPGA):   259.31 ms
# [이미지 #870] Time (CPU):  3309.53 ms | Time (FPGA):   259.60 ms
# [이미지 #871] Time (CPU):  3312.80 ms | Time (FPGA):   258.92 ms
# [이미지 #872] Time (CPU):  3315.59 ms | Time (FPGA):   259.90 ms
# [이미지 #873] Time (CPU):  3311.81 ms | Time (FPGA):   259.98 ms
# [이미지 #874] Time (CPU):  3311.24 ms | Time (FPGA):   259.65 ms
# [이미지 #875] Time (CPU):  3308.11 ms | Time (FPGA):   259.67 ms
# [이미지 #876] Time (CPU):  3312.98 ms | Time (FPGA):   259.52 ms
# [이미지 #877] Time (CPU):  3307.59 ms | Time (FPGA):   259.42 ms
# [이미지 #878] Time (CPU):  3310.38 ms | Time (FPGA):   260.53 ms
# [이미지 #879] Time (CPU):  3308.95 ms | Time (FPGA):   259.55 ms
# [이미지 #880] Time (CPU):  3309.71 ms | Time (FPGA):   260.52 ms
# [이미지 #881] Time (CPU):  3314.79 ms | Time (FPGA):   258.34 ms
# [이미지 #882] Time (CPU):  3310.70 ms | Time (FPGA):   258.16 ms
# [이미지 #883] Time (CPU):  3308.85 ms | Time (FPGA):   258.17 ms
# [이미지 #884] Time (CPU):  3309.55 ms | Time (FPGA):   258.05 ms
# [이미지 #885] Time (CPU):  3307.69 ms | Time (FPGA):   258.47 ms
# [이미지 #886] Time (CPU):  3310.01 ms | Time (FPGA):   261.77 ms
# [이미지 #887] Time (CPU):  3307.22 ms | Time (FPGA):   258.10 ms
# [이미지 #888] Time (CPU):  3310.84 ms | Time (FPGA):   258.00 ms
# [이미지 #889] Time (CPU):  3318.65 ms | Time (FPGA):   259.89 ms
# [이미지 #890] Time (CPU):  3311.65 ms | Time (FPGA):   258.12 ms
# [이미지 #891] Time (CPU):  3308.85 ms | Time (FPGA):   263.37 ms
# [이미지 #892] Time (CPU):  3311.93 ms | Time (FPGA):   260.68 ms
# [이미지 #893] Time (CPU):  3307.74 ms | Time (FPGA):   257.84 ms
# [이미지 #894] Time (CPU):  3332.91 ms | Time (FPGA):   258.26 ms
# [이미지 #895] Time (CPU):  3309.09 ms | Time (FPGA):   258.81 ms
# [이미지 #896] Time (CPU):  3306.65 ms | Time (FPGA):   258.34 ms
# [이미지 #897] Time (CPU):  3307.53 ms | Time (FPGA):   270.18 ms
# [이미지 #898] Time (CPU):  3311.87 ms | Time (FPGA):   261.55 ms
# [이미지 #899] Time (CPU):  3310.36 ms | Time (FPGA):   259.53 ms
# [이미지 #900] Time (CPU):  3308.53 ms | Time (FPGA):   258.57 ms
# [이미지 #901] Time (CPU):  3312.76 ms | Time (FPGA):   258.13 ms
# [이미지 #902] Time (CPU):  3315.01 ms | Time (FPGA):   259.57 ms
# [이미지 #903] Time (CPU):  3311.38 ms | Time (FPGA):   259.27 ms
# [이미지 #904] Time (CPU):  3311.22 ms | Time (FPGA):   259.31 ms
# [이미지 #905] Time (CPU):  3310.14 ms | Time (FPGA):   259.87 ms
# [이미지 #906] Time (CPU):  3319.86 ms | Time (FPGA):   259.24 ms
# [이미지 #907] Time (CPU):  3312.66 ms | Time (FPGA):   260.58 ms
# [이미지 #908] Time (CPU):  3310.92 ms | Time (FPGA):   257.99 ms
# [이미지 #909] Time (CPU):  3310.49 ms | Time (FPGA):   258.31 ms
# [이미지 #910] Time (CPU):  3309.86 ms | Time (FPGA):   258.06 ms
# [이미지 #911] Time (CPU):  3308.03 ms | Time (FPGA):   258.25 ms
# [이미지 #912] Time (CPU):  3310.22 ms | Time (FPGA):   257.97 ms
# [이미지 #913] Time (CPU):  3308.49 ms | Time (FPGA):   258.12 ms
# [이미지 #914] Time (CPU):  3319.57 ms | Time (FPGA):   258.55 ms
# [이미지 #915] Time (CPU):  3314.28 ms | Time (FPGA):   259.32 ms
# [이미지 #916] Time (CPU):  3310.23 ms | Time (FPGA):   258.36 ms
# [이미지 #917] Time (CPU):  3313.09 ms | Time (FPGA):   257.68 ms
# [이미지 #918] Time (CPU):  3309.27 ms | Time (FPGA):   259.57 ms
# [이미지 #919] Time (CPU):  3308.63 ms | Time (FPGA):   259.66 ms
# [이미지 #920] Time (CPU):  3308.50 ms | Time (FPGA):   259.20 ms
# [이미지 #921] Time (CPU):  3307.16 ms | Time (FPGA):   260.99 ms
# [이미지 #922] Time (CPU):  3313.98 ms | Time (FPGA):   261.33 ms
# [이미지 #923] Time (CPU):  3327.73 ms | Time (FPGA):   260.16 ms
# [이미지 #924] Time (CPU):  3316.75 ms | Time (FPGA):   260.73 ms
# [이미지 #925] Time (CPU):  3312.92 ms | Time (FPGA):   261.93 ms
# [이미지 #926] Time (CPU):  3314.72 ms | Time (FPGA):   259.55 ms
# [이미지 #927] Time (CPU):  3329.65 ms | Time (FPGA):   259.93 ms
# [이미지 #928] Time (CPU):  3317.32 ms | Time (FPGA):   258.89 ms
# [이미지 #929] Time (CPU):  3311.47 ms | Time (FPGA):   259.16 ms
# [이미지 #930] Time (CPU):  3313.65 ms | Time (FPGA):   260.68 ms
# [이미지 #931] Time (CPU):  3320.96 ms | Time (FPGA):   260.46 ms
# [이미지 #932] Time (CPU):  3313.48 ms | Time (FPGA):   262.50 ms
# [이미지 #933] Time (CPU):  3313.45 ms | Time (FPGA):   259.87 ms
# [이미지 #934] Time (CPU):  3314.43 ms | Time (FPGA):   260.44 ms
# [이미지 #935] Time (CPU):  3309.96 ms | Time (FPGA):   259.91 ms
# [이미지 #936] Time (CPU):  3312.55 ms | Time (FPGA):   260.93 ms
# [이미지 #937] Time (CPU):  3313.59 ms | Time (FPGA):   259.41 ms
# [이미지 #938] Time (CPU):  3312.49 ms | Time (FPGA):   259.90 ms
# [이미지 #939] Time (CPU):  3315.28 ms | Time (FPGA):   263.03 ms
# [이미지 #940] Time (CPU):  3325.68 ms | Time (FPGA):   260.15 ms
# [이미지 #941] Time (CPU):  3313.82 ms | Time (FPGA):   259.35 ms
# [이미지 #942] Time (CPU):  3315.14 ms | Time (FPGA):   258.02 ms
# [이미지 #943] Time (CPU):  3312.19 ms | Time (FPGA):   260.22 ms
# [이미지 #944] Time (CPU):  3307.81 ms | Time (FPGA):   258.47 ms
# [이미지 #945] Time (CPU):  3309.88 ms | Time (FPGA):   257.97 ms
# [이미지 #946] Time (CPU):  3311.12 ms | Time (FPGA):   260.13 ms
# [이미지 #947] Time (CPU):  3318.49 ms | Time (FPGA):   259.16 ms
# [이미지 #948] Time (CPU):  3315.03 ms | Time (FPGA):   258.44 ms
# [이미지 #949] Time (CPU):  3313.56 ms | Time (FPGA):   259.33 ms
# [이미지 #950] Time (CPU):  3308.59 ms | Time (FPGA):   259.39 ms
# [이미지 #951] Time (CPU):  3309.39 ms | Time (FPGA):   258.62 ms
# [이미지 #952] Time (CPU):  3315.78 ms | Time (FPGA):   258.72 ms
# [이미지 #953] Time (CPU):  3313.42 ms | Time (FPGA):   258.30 ms
# [이미지 #954] Time (CPU):  3311.34 ms | Time (FPGA):   259.12 ms
# [이미지 #955] Time (CPU):  3313.64 ms | Time (FPGA):   259.02 ms
# [이미지 #956] Time (CPU):  3317.04 ms | Time (FPGA):   257.87 ms
# [이미지 #957] Time (CPU):  3310.09 ms | Time (FPGA):   259.80 ms
# [이미지 #958] Time (CPU):  3308.99 ms | Time (FPGA):   259.52 ms
# [이미지 #959] Time (CPU):  3309.96 ms | Time (FPGA):   260.05 ms
# [이미지 #960] Time (CPU):  3327.89 ms | Time (FPGA):   343.19 ms
# [이미지 #961] Time (CPU):  3311.45 ms | Time (FPGA):   258.93 ms
# [이미지 #962] Time (CPU):  3312.83 ms | Time (FPGA):   258.02 ms
# [이미지 #963] Time (CPU):  3317.02 ms | Time (FPGA):   258.06 ms
# [이미지 #964] Time (CPU):  3313.35 ms | Time (FPGA):   258.87 ms
# [이미지 #965] Time (CPU):  3321.97 ms | Time (FPGA):   258.72 ms
# [이미지 #966] Time (CPU):  3311.17 ms | Time (FPGA):   260.57 ms
# [이미지 #967] Time (CPU):  3315.04 ms | Time (FPGA):   257.95 ms
# [이미지 #968] Time (CPU):  3308.88 ms | Time (FPGA):   257.59 ms
# [이미지 #969] Time (CPU):  3310.02 ms | Time (FPGA):   257.85 ms
# [이미지 #970] Time (CPU):  3309.20 ms | Time (FPGA):   257.89 ms
# [이미지 #971] Time (CPU):  3313.78 ms | Time (FPGA):   262.04 ms
# [이미지 #972] Time (CPU):  3310.30 ms | Time (FPGA):   261.29 ms
# [이미지 #973] Time (CPU):  3320.99 ms | Time (FPGA):   261.54 ms
# [이미지 #974] Time (CPU):  3316.12 ms | Time (FPGA):   262.37 ms
# [이미지 #975] Time (CPU):  3315.62 ms | Time (FPGA):   261.79 ms
# [이미지 #976] Time (CPU):  3312.20 ms | Time (FPGA):   263.69 ms
# [이미지 #977] Time (CPU):  3312.74 ms | Time (FPGA):   262.81 ms
# [이미지 #978] Time (CPU):  3310.76 ms | Time (FPGA):   262.71 ms
# [이미지 #979] Time (CPU):  3313.30 ms | Time (FPGA):   264.34 ms
# [이미지 #980] Time (CPU):  3311.35 ms | Time (FPGA):   261.49 ms
# [이미지 #981] Time (CPU):  3317.34 ms | Time (FPGA):   263.56 ms
# [이미지 #982] Time (CPU):  3303.56 ms | Time (FPGA):   262.57 ms
# [이미지 #983] Time (CPU):  3307.34 ms | Time (FPGA):   261.98 ms
# [이미지 #984] Time (CPU):  3309.16 ms | Time (FPGA):   261.39 ms
# [이미지 #985] Time (CPU):  3312.02 ms | Time (FPGA):   262.36 ms
# [이미지 #986] Time (CPU):  3304.53 ms | Time (FPGA):   262.28 ms
# [이미지 #987] Time (CPU):  3307.23 ms | Time (FPGA):   262.43 ms
# [이미지 #988] Time (CPU):  3304.33 ms | Time (FPGA):   265.46 ms
# [이미지 #989] Time (CPU):  3307.00 ms | Time (FPGA):   263.25 ms
# [이미지 #990] Time (CPU):  3312.94 ms | Time (FPGA):   262.50 ms
# [이미지 #991] Time (CPU):  3317.63 ms | Time (FPGA):   261.79 ms
# [이미지 #992] Time (CPU):  3316.29 ms | Time (FPGA):   261.31 ms
# [이미지 #993] Time (CPU):  3319.13 ms | Time (FPGA):   355.95 ms
# [이미지 #994] Time (CPU):  3316.82 ms | Time (FPGA):   262.58 ms
# [이미지 #995] Time (CPU):  3310.94 ms | Time (FPGA):   261.48 ms
# [이미지 #996] Time (CPU):  3305.70 ms | Time (FPGA):   261.40 ms
# [이미지 #997] Time (CPU):  3310.24 ms | Time (FPGA):   261.42 ms
# [이미지 #998] Time (CPU):  3320.87 ms | Time (FPGA):   263.52 ms
# [이미지 #999] Time (CPU):  3312.85 ms | Time (FPGA):   261.31 ms
# 1000개 이미지 테스트 완료. 루프 종료.
#
# 공용 DMA 버퍼 해제 중...
# 공용 DMA 버퍼 모두 해제됨.
#
# ==================================================
#      *PYNQ 테스트* 최종 정확도 비교 결과 (1000개 샘플)
# ==================================================
#   - [A] PyTorch CPU 추론 정확도: 	80.70 % (807/1000)
#   - [B] PYNQ FPGA 가속 추론 정확도: 	80.60 % (806/1000)
# --------------------------------------------------
#   - 정확도 차이 (A - B): +0.10 %
#
# ==================================================
#      *PYNQ 테스트* 최종 성능 비교 결과 (1000개 샘플)
# ==================================================
#   - [A] CPU 평균 추론 시간: 	3314.74 ms/image
#   - [B] FPGA 평균 추론 시간: 	260.89 ms/image
# --------------------------------------------------
#   - FPGA 가속 성능: 12.71x (CPU 대비)
#
# PYNQ 추론 스크립트 종료.
